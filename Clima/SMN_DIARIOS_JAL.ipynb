# %% [markdown]
# <a href="https://colab.research.google.com/github/armandochernandez-ai/Curso-python-slava/blob/main/Clima/SMN_DIARIOS_JAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
import time
import re
import os
import sys
from datetime import datetime, timedelta
from google.colab import files, drive
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# Configuración
BASE_URL = "https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal"
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'es-MX,es;q=0.9',
}

# Variables disponibles en los datos diarios con nuevos nombres
VARIABLES_DIARIAS = ['p', 'evap', 'tmax', 'tmin']
VARIABLES_ORIGINALES = ['PRECIP', 'EVAP', 'TMAX', 'TMIN']
VARIABLE_MAPPING = dict(zip(VARIABLES_ORIGINALES, VARIABLES_DIARIAS))

# Valores que deben ser reemplazados por NA (incluyendo NULO)
VALORES_NULOS = ['', 'N/D', '-', '--', '---', '////', '****', '*****', 'NULL', 'null', 'N/A', 'n/a', 'NULO']

def setup_colab_environment():
    """Configura el entorno de Google Colab"""
    print("🔧 Configurando entorno de Google Colab...")

    # Montar Google Drive (opcional)
    mount_drive = input("¿Deseas montar Google Drive? (s/n): ").lower().strip()
    if mount_drive == 's':
        drive.mount('/content/drive')
        print("✅ Google Drive montado correctamente")
        return "/content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS"
    else:
        print("📁 Usando almacenamiento temporal de Colab")
        return "/content/Clima_Jalisco/DATOS_DIARIOS"

def configurar_directorios(directorio_base=None):
    """Configura los directorios de salida"""
    if directorio_base is None:
        directorio_base = setup_colab_environment()

    directorio_datos = directorio_base

    os.makedirs(directorio_datos, exist_ok=True)

    print(f"📂 Directorio de trabajo: {os.path.abspath(directorio_datos)}")
    return directorio_datos

def descargar_datos_estacion(clave):
    """Descarga los datos diarios de una estación específica"""
    url = f"{BASE_URL}/dia{clave}.txt"
    try:
        print(f"  📥 Descargando de: {url}")
        response = requests.get(url, headers=HEADERS, timeout=30)
        response.raise_for_status()

        # Verificar si el contenido es válido
        if len(response.text.strip()) < 50:
            print(f"  ⚠️ Contenido insuficiente para estación {clave}")
            return None

        return response.text
    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            print(f"  ❌ Estación {clave} no encontrada (404)")
        else:
            print(f"  ❌ Error HTTP {e.response.status_code} para estación {clave}")
        return None
    except Exception as e:
        print(f"  ❌ Error descargando datos para estación {clave}: {str(e)}")
        return None

def extraer_info_basica(contenido):
    """Extrae la información básica de la estación"""
    datos = {
        'Codigo': '',
        'site': '',
        'estado': 'Jalisco',
        'municipio': '',
        'situacion': '',
        'lat': '',
        'lon': '',
        'alt': ''
    }

    lineas = contenido.split('\n')
    for linea in lineas:
        linea = linea.strip()
        if 'ESTACIÓN  :' in linea:
            datos['Codigo'] = linea.split(':')[1].strip()
        elif 'NOMBRE    :' in linea:
            datos['site'] = linea.split(':')[1].strip()
        elif 'MUNICIPIO :' in linea:
            datos['municipio'] = linea.split(':')[1].strip()
        elif 'SITUACIÓN :' in linea:
            datos['situacion'] = linea.split(':')[1].strip()
        elif 'LATITUD   :' in linea:
            datos['lat'] = linea.split(':')[1].replace('°', '').strip()
        elif 'LONGITUD  :' in linea:
            datos['lon'] = linea.split(':')[1].replace('°', '').strip()
        elif 'ALTITUD   :' in linea:
            datos['alt'] = linea.split(':')[1].replace('msnm', '').strip()

    return datos

def limpiar_valor(valor):
    """Limpia y valida los valores, reemplazando nulos por NA"""
    if valor is None:
        return 'NA'

    valor_str = str(valor).strip()

    # Si está vacío o en la lista de valores nulos (incluyendo NULO)
    if not valor_str or valor_str in VALORES_NULOS:
        return 'NA'

    # Si son solo asteriscos o caracteres no válidos
    if re.match(r'^[*\-/\s]+$', valor_str):
        return 'NA'

    return valor_str

def convertir_fecha(fecha_str):
    """Convierte diferentes formatos de fecha a objeto datetime"""
    # Intentar formato YYYY-MM-DD
    try:
        return datetime.strptime(fecha_str, '%Y-%m-%d')
    except ValueError:
        pass

    # Intentar formato DD/MM/YYYY
    try:
        return datetime.strptime(fecha_str, '%d/%m/%Y')
    except ValueError:
        pass

    # Intentar formato D/M/YYYY
    try:
        return datetime.strptime(fecha_str, '%d/%m/%Y')
    except ValueError:
        pass

    print(f"    ⚠️ Advertencia: No se pudo parsear la fecha: {fecha_str}")
    return None

def completar_fechas_faltantes(datos_diarios):
    """Completa las fechas faltantes en los datos con registros NA"""
    if not datos_diarios:
        return []

    # Convertir fechas y ordenar
    datos_con_fechas = []
    for registro in datos_diarios:
        fecha_dt = convertir_fecha(registro['date'])
        if fecha_dt:
            datos_con_fechas.append((fecha_dt, registro))

    if not datos_con_fechas:
        return datos_diarios

    datos_con_fechas.sort(key=lambda x: x[0])

    # Encontrar rango de fechas
    fecha_inicio = datos_con_fechas[0][0]
    fecha_fin = datos_con_fechas[-1][0]

    print(f"    📅 Rango de fechas: {fecha_inicio.strftime('%Y-%m-%d')} a {fecha_fin.strftime('%Y-%m-%d')}")

    # Crear conjunto de fechas existentes
    fechas_existentes = {fecha for fecha, _ in datos_con_fechas}

    # Generar todas las fechas en el rango
    fecha_actual = fecha_inicio
    datos_completos = []

    while fecha_actual <= fecha_fin:
        if fecha_actual in fechas_existentes:
            # Buscar el registro existente
            for fecha_dt, registro in datos_con_fechas:
                if fecha_dt == fecha_actual:
                    datos_completos.append(registro)
                    break
        else:
            # Crear registro con NA para fecha faltante
            registro_na = {
                'date': fecha_actual.strftime('%Y-%m-%d'),
                'p': 'NA',
                'evap': 'NA',
                'tmax': 'NA',
                'tmin': 'NA'
            }
            datos_completos.append(registro_na)

        fecha_actual += timedelta(days=1)

    print(f"    ✅ Después de completar fechas: {len(datos_completos)} registros")
    return datos_completos

def estandarizar_formato_fecha(datos_diarios):
    """Estandariza el formato de fecha a YYYY-MM-DD"""
    for registro in datos_diarios:
        fecha_dt = convertir_fecha(registro['date'])
        if fecha_dt:
            registro['date'] = fecha_dt.strftime('%Y-%m-%d')
    return datos_diarios

def parsear_datos_diarios(contenido):
    """Extrae los datos diarios del contenido, manejando valores NULO"""
    lineas = contenido.split('\n')
    datos_diarios = []

    # Bandera para indicar cuando empezar a leer datos
    empezar_datos = False
    patron_fecha_guion = re.compile(r'^\d{4}-\d{1,2}-\d{1,2}')  # Formato YYYY-MM-DD
    patron_fecha_slash = re.compile(r'^\d{1,2}/\d{1,2}/\d{4}')  # Formato DD/MM/YYYY

    # Buscar la línea de encabezados
    for i, linea in enumerate(lineas):
        linea = linea.strip()

        # Buscar el inicio de la tabla de datos
        if 'FECHA' in linea and any(var in linea for var in VARIABLES_ORIGINALES):
            empezar_datos = True
            # Saltar la siguiente línea (unidades) si existe
            continue

        # Si estamos en la sección de datos, procesar línea
        if empezar_datos and linea:
            # Verificar si es una línea de datos (comienza con fecha en formato YYYY-MM-DD o DD/MM/YYYY)
            if patron_fecha_guion.match(linea) or patron_fecha_slash.match(linea):
                # Dividir por tabs (parece que están separados por tabs en el ejemplo)
                partes = linea.split('\t')

                # Si no hay tabs, intentar con espacios múltiples
                if len(partes) < 2:
                    partes = re.split(r'\s{2,}', linea)

                # Si aún no funciona, usar split simple
                if len(partes) < 2:
                    partes = linea.split()

                # Filtrar partes vacías
                partes = [p.strip() for p in partes if p.strip()]

                # Debe tener al menos la fecha
                if len(partes) >= 1:
                    fecha = partes[0]

                    # Procesar valores para cada variable
                    valores = {}

                    # Asignar valores según posición esperada
                    # Orden esperado: FECHA, PRECIP, EVAP, TMAX, TMIN
                    if len(partes) > 1:
                        valores['p'] = limpiar_valor(partes[1])
                    else:
                        valores['p'] = 'NA'

                    if len(partes) > 2:
                        valores['evap'] = limpiar_valor(partes[2])
                    else:
                        valores['evap'] = 'NA'

                    if len(partes) > 3:
                        valores['tmax'] = limpiar_valor(partes[3])
                    else:
                        valores['tmax'] = 'NA'

                    if len(partes) > 4:
                        valores['tmin'] = limpiar_valor(partes[4])
                    else:
                        valores['tmin'] = 'NA'

                    # Crear registro
                    registro = {
                        'date': fecha,
                        **valores
                    }
                    datos_diarios.append(registro)

            # Si encontramos líneas que indican el final de los datos
            elif any(palabra in linea.upper() for palabra in ['PROMEDIO', 'TOTAL', 'MEDIA', 'FIN DE DATOS']):
                break

    # Si no encontramos datos con el método anterior, intentar método más flexible
    if not datos_diarios:
        datos_diarios = parsear_datos_flexible(contenido)

    print(f"    📊 Se extrajeron {len(datos_diarios)} registros diarios")

    # Completar fechas faltantes
    datos_diarios = estandarizar_formato_fecha(datos_diarios)
    datos_diarios = completar_fechas_faltantes(datos_diarios)

    # Depuración: mostrar primeros 3 registros si hay datos
    if datos_diarios and len(datos_diarios) > 0:
        print(f"    📍 Primer registro: {datos_diarios[0]}")
        if len(datos_diarios) > 1:
            print(f"    📍 Último registro: {datos_diarios[-1]}")

    return datos_diarios

def parsear_datos_flexible(contenido):
    """Método más flexible para extraer datos cuando el método principal falla"""
    lineas = contenido.split('\n')
    datos_diarios = []

    # Patrones de fecha
    patron_fecha_guion = re.compile(r'^\d{4}-\d{1,2}-\d{1,2}')  # YYYY-MM-DD
    patron_fecha_slash = re.compile(r'^\d{1,2}/\d{1,2}/\d{4}')   # DD/MM/YYYY

    # Buscar cualquier línea que empiece con fecha
    for linea in lineas:
        linea = linea.strip()

        # Verificar si es una línea de datos (comienza con fecha)
        if patron_fecha_guion.match(linea) or patron_fecha_slash.match(linea):
            # Dividir por cualquier tipo de espacio (tabs, espacios múltiples)
            partes = re.split(r'\t|\s{2,}', linea)

            # Si no funciona, usar split simple
            if len(partes) < 2:
                partes = linea.split()

            # Filtrar partes vacías
            partes = [p.strip() for p in partes if p.strip()]

            if len(partes) >= 1:
                fecha = partes[0]
                valores = {}

                # Mapear las variables por posición
                for i, var in enumerate(VARIABLES_DIARIAS):
                    if i + 1 < len(partes):
                        valores[var] = limpiar_valor(partes[i + 1])
                    else:
                        valores[var] = 'NA'

                registro = {'date': fecha, **valores}
                datos_diarios.append(registro)

    return datos_diarios

def guardar_datos_estacion(directorio_salida, estacion_info, datos_diarios):
    """Guarda los datos diarios de una estación en archivo CSV"""
    if not datos_diarios:
        print(f"  ⚠️ No hay datos diarios para guardar de la estación {estacion_info['Codigo']}")
        return False

    # Crear nombre de archivo
    archivo_csv = os.path.join(directorio_salida, f"diarios_{estacion_info['Codigo']}.csv")

    # Campos del CSV con nuevos nombres
    campos = ['Codigo', 'site', 'municipio', 'lat', 'lon', 'alt', 'date'] + VARIABLES_DIARIAS

    try:
        # Escribir datos
        with open(archivo_csv, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=campos)
            writer.writeheader()

            for registro in datos_diarios:
                fila = {
                    'Codigo': estacion_info['Codigo'],
                    'site': estacion_info['site'],
                    'municipio': estacion_info['municipio'],
                    'lat': estacion_info['lat'],
                    'lon': estacion_info['lon'],
                    'alt': estacion_info['alt'],
                    'date': registro['date'],
                    'p': registro.get('p', 'NA'),
                    'evap': registro.get('evap', 'NA'),
                    'tmax': registro.get('tmax', 'NA'),
                    'tmin': registro.get('tmin', 'NA')
                }
                writer.writerow(fila)

        print(f"  💾 Datos guardados en: {archivo_csv}")
        return True
    except Exception as e:
        print(f"  ❌ Error guardando archivo para estación {estacion_info['Codigo']}: {str(e)}")
        return False

def guardar_datos_unidos(directorio_salida, estacion_info, datos_diarios):
    """Guarda todos los datos en un archivo CSV unificado"""
    if not datos_diarios:
        return

    archivo_unido = os.path.join(directorio_salida, "datos_diarios_unidos.csv")

    # Campos del CSV con nuevos nombres
    campos = ['Codigo', 'site', 'municipio', 'lat', 'lon', 'alt', 'date'] + VARIABLES_DIARIAS

    try:
        # Verificar si el archivo existe para no sobrescribir el encabezado
        modo = 'a' if os.path.exists(archivo_unido) else 'w'

        with open(archivo_unido, modo, newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=campos)

            if modo == 'w':
                writer.writeheader()
                print(f"  📦 Creando archivo unificado: {archivo_unido}")

            for registro in datos_diarios:
                fila = {
                    'Codigo': estacion_info['Codigo'],
                    'site': estacion_info['site'],
                    'municipio': estacion_info['municipio'],
                    'lat': estacion_info['lat'],
                    'lon': estacion_info['lon'],
                    'alt': estacion_info['alt'],
                    'date': registro['date'],
                    'p': registro.get('p', 'NA'),
                    'evap': registro.get('evap', 'NA'),
                    'tmax': registro.get('tmax', 'NA'),
                    'tmin': registro.get('tmin', 'NA')
                }
                writer.writerow(fila)
    except Exception as e:
        print(f"  ❌ Error actualizando archivo unificado: {str(e)}")

def procesar_estacion(clave, directorio_salida):
    """Procesa una estación individual"""
    print(f"🔍 Procesando estación: {clave}")

    contenido = descargar_datos_estacion(clave)

    if not contenido:
        print(f"  ❌ No se pudieron obtener datos para la estación {clave}")
        return False

    # Extraer información básica de la estación
    estacion_info = extraer_info_basica(contenido)

    # Si no se pudo extraer la clave, usar la clave proporcionada
    if not estacion_info['Codigo']:
        estacion_info['Codigo'] = clave

    print(f"  🏢 Estación: {estacion_info['site']} ({estacion_info['municipio']})")

    # Extraer datos diarios
    datos_diarios = parsear_datos_diarios(contenido)

    if datos_diarios:
        # Guardar en archivo individual de la estación
        guardar_datos_estacion(directorio_salida, estacion_info, datos_diarios)

        # Guardar en archivo unificado
        guardar_datos_unidos(directorio_salida, estacion_info, datos_diarios)
        return True
    else:
        print(f"  ⚠️ No se encontraron datos diarios para esta estación")
        return False

    time.sleep(1)  # Espera entre descargas para no saturar el servidor

def leer_archivo_estaciones(nombre_archivo):
    """Lee el archivo de estaciones con manejo de codificaciones"""
    try:
        with open(nombre_archivo, 'r', encoding='utf-8') as f:
            lineas = [linea.strip() for linea in f.readlines() if linea.strip()]
            print(f"📖 Se leyeron {len(lineas)} estaciones del archivo: {nombre_archivo}")
            return lineas
    except UnicodeDecodeError:
        try:
            with open(nombre_archivo, 'r', encoding='latin-1') as f:
                lineas = [linea.strip() for linea in f.readlines() if linea.strip()]
                print(f"📖 Se leyeron {len(lineas)} estaciones del archivo (codificación latin-1): {nombre_archivo}")
                return lineas
        except Exception as e:
            print(f"❌ Error leyendo archivo de estaciones {nombre_archivo}: {str(e)}")
            return []
    except FileNotFoundError:
        print(f"❌ Archivo no encontrado: {nombre_archivo}")
        return []
    except Exception as e:
        print(f"❌ Error leyendo archivo de estaciones {nombre_archivo}: {str(e)}")
        return []

def upload_estaciones_file():
    """Permite subir un archivo de estaciones en Colab"""
    print("\n📤 Subir archivo de estaciones")
    print("=" * 50)
    uploaded = files.upload()

    for filename, content in uploaded.items():
        if filename.endswith('.txt'):
            # Save in the default directory where other files are saved temporarily
            with open('estaciones.txt', 'wb') as f:
                f.write(content)
            print(f"✅ Archivo '{filename}' guardado como 'estaciones.txt'")
            return 'estaciones.txt'

    print("❌ No se subió ningún archivo .txt válido")
    return None

def solicitar_clave_estacion():
    """Solicita al usuario una clave de estación cuando no existe el archivo"""
    print("\n" + "="*60)
    print("📋 ARCHIVO DE ESTACIONES NO ENCONTRADO")
    print("="*60)
    print("El archivo 'estaciones.txt' no existe o está vacío en la ubicación esperada.")
    print("Puede:")
    print("1. Subir un archivo de estaciones")
    print("2. Proporcionar una clave de estación individual")
    print("3. Usar estaciones por defecto")
    print("\nEjemplos de claves de estación en Jalisco:")
    print("  14001, 14002, 14003, 14004, 14005, etc.")

    while True:
        print("\nOpciones:")
        print("1. Subir archivo de estaciones")
        print("2. Ingresar clave manualmente")
        print("3. Usar estaciones por defecto")
        print("4. Salir")

        opcion = input("\nSeleccione una opción (1-4): ").strip()

        if opcion == '1':
            archivo = upload_estaciones_file()
            if archivo:
                return leer_archivo_estaciones(archivo)
        elif opcion == '2':
            clave = input("Ingrese la clave de estación: ").strip()
            if clave and clave.isdigit():
                return [clave]
            else:
                print("❌ Error: La clave debe ser un número.")
        elif opcion == '3':
            print("✅ Usando estaciones por defecto de Jalisco")
            return ['14001', '14002', '14003', '14004', '14005',
                   '14006', '14007', '14008', '14009', '14010',
                   '14011', '14012', '14013', '14014', '14015']
        elif opcion == '4':
            return None
        else:
            print("❌ Opción no válida. Intente nuevamente.")

def generar_reporte_estaciones(directorio_salida):
    """Genera un reporte de las estaciones procesadas"""
    archivos = [f for f in os.listdir(directorio_salida) if f.startswith('diarios_') and f.endswith('.csv')]

    reporte = []
    for archivo in archivos:
        clave = archivo.replace('diarios_', '').replace('.csv', '')
        ruta_archivo = os.path.join(directorio_salida, archivo)

        try:
            with open(ruta_archivo, 'r', encoding='utf-8') as f:
                lineas = f.readlines()
                if len(lineas) > 1:  # Tiene encabezado y al menos un dato
                    num_registros = len(lineas) - 1
                    reporte.append({
                        'Codigo': clave,
                        'archivo': archivo,
                        'registros': num_registros
                    })
        except:
            continue

    # Guardar reporte
    if reporte:
        archivo_reporte = os.path.join(directorio_salida, "reporte_estaciones.csv")
        with open(archivo_reporte, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['Codigo', 'archivo', 'registros'])
            writer.writeheader()
            writer.writerows(reporte)

        print(f"\n📊 Reporte generado: {archivo_reporte}")
        print(f"📈 Total de estaciones con datos: {len(reporte)}")

        # Mostrar resumen
        for est in reporte:
            print(f"  📍 {est['Codigo']}: {est['registros']} registros")

        return len(reporte)
    return 0

def descargar_archivos_resultado(directorio_salida):
    """Permite descargar los archivos resultantes en Colab"""
    print("\n📥 DESCARGAR RESULTADOS")
    print("=" * 40)

    archivos_descargables = []

    # Buscar archivos CSV en el directorio
    for archivo in os.listdir(directorio_salida):
        if archivo.endswith('.csv'):
            archivos_descargables.append(os.path.join(directorio_salida, archivo))

    if archivos_descargables:
        print("Archivos disponibles para descargar:")
        for i, archivo in enumerate(archivos_descargables, 1):
            print(f"  {i}. {os.path.basename(archivo)}")

        descargar = input("\n¿Desea descargar todos los archivos en su computadora? (s/n): ").lower().strip()
        if descargar == 's':
            # Crear archivo zip con todos los resultados
            import zipfile
            zip_path = os.path.join(directorio_salida, "resultados_clima.zip")

            with zipfile.ZipFile(zip_path, 'w') as zipf:
                for archivo in archivos_descargables:
                    zipf.write(archivo, os.path.basename(archivo))

            print("📦 Descargando archivo comprimido...")
            files.download(zip_path)
            print("✅ Descarga completada")
    else:
        print("❌ No hay archivos para descargar")

def mostrar_resumen_estadisticas(directorio_salida):
    """Muestra un resumen estadístico de los datos"""
    archivo_unido = os.path.join(directorio_salida, "datos_diarios_unidos.csv")

    if os.path.exists(archivo_unido):
        print("\n📊 RESUMEN ESTADÍSTICO")
        print("=" * 40)

        try:
            # Use low_memory=False to avoid DtypeWarning for mixed types
            df = pd.read_csv(archivo_unido, low_memory=False)
            print(f"Total de registros: {len(df)}")
            print(f"Total de estaciones: {df['Codigo'].nunique()}")

            # Convert date column to datetime objects, coercing errors
            df['date'] = pd.to_datetime(df['date'], errors='coerce')
            df = df.dropna(subset=['date']) # Remove rows where date conversion failed

            if not df.empty:
                print(f"Rango de fechas: {df['date'].min().strftime('%Y-%m-%d')} a {df['date'].max().strftime('%Y-%m-%d')}")
            else:
                 print("No valid dates found in the data.")


            # Estadísticas por variable - convert to numeric, coercing errors
            variables = ['p', 'evap', 'tmax', 'tmin']
            for var in variables:
                # Convert to numeric, invalid parsing will be set as NaN
                df[var] = pd.to_numeric(df[var], errors='coerce')
                datos_validos = df[var].dropna() # Drop NaN values

                if len(datos_validos) > 0:
                    print(f"\n{var.upper()}:")
                    print(f"  Registros válidos: {len(datos_validos)}")
                    print(f"  Promedio: {datos_validos.mean():.2f}")
                    print(f"  Mínimo: {datos_validos.min():.2f}")
                    print(f"  Máximo: {datos_validos.max():.2f}")
                else:
                    print(f"\n{var.upper()}: No valid numeric data found.")


        except Exception as e:
            print(f"❌ Error generando estadísticas: {e}")
    else:
        print(f"\n📊 RESUMEN ESTADÍSTICO: Archivo unificado '{archivo_unido}' no encontrado.")

def main():
    print("🌤️ SISTEMA DE EXTRACCIÓN DE DATOS METEOROLÓGICOS DIARIOS DE JALISCO")
    print("=" * 70)
    print("Variables: date, p, evap, tmax, tmin")
    print("Valores nulos (incluyendo 'NULO') se reemplazan por: NA")
    print("Se completarán fechas faltantes con registros NA")

    # Configurar directorios
    directorio_salida = configurar_directorios()

    # Determine the expected path for estaciones.txt
    # If Google Drive is mounted, check the specified path
    if "/content/drive" in directorio_salida: # Simple check if Drive was likely mounted
        archivo_entrada = os.path.join(directorio_salida, 'estaciones.txt')
    else:
        # Otherwise, check the default temporary location
        archivo_entrada = 'estaciones.txt'

    estaciones = []

    print(f"\n🔎 Buscando archivo de estaciones en: {archivo_entrada}")
    if os.path.exists(archivo_entrada) and os.path.getsize(archivo_entrada) > 0:
        estaciones = leer_archivo_estaciones(archivo_entrada)
    else:
        print(f"📄 Archivo {archivo_entrada} no encontrado o está vacío")
        estaciones = solicitar_clave_estacion()

        # If the user didn't provide valid input
        if not estaciones:
            print("❌ No se proporcionó una clave de estación válida. Saliendo.")
            return

    if estaciones:
        total = len(estaciones)
        print(f"\n🔄 Procesando {total} estaciones...")

        exitosas = 0
        for i, clave in enumerate(estaciones, 1):
            print(f"\n[{i}/{total}] ", end="")
            if procesar_estacion(clave, directorio_salida):
                exitosas += 1
            time.sleep(1)  # Espera entre descargas para no saturar el servidor

        print(f"\n🎉 ¡PROCESO COMPLETADO!")
        print(f"✅ Estaciones con datos extraídos: {exitosas}/{total}")
        print(f"📂 Datos guardados en: {directorio_salida}")

        # Generar reporte
        generar_reporte_estaciones(directorio_salida)

        # Mostrar estadísticas
        mostrar_resumen_estadisticas(directorio_salida)

        # Ofrecer descargar resultados
        descargar_archivos_resultado(directorio_salida)

    else:
        print("❌ No se encontraron estaciones para procesar")

if __name__ == "__main__":
    main()
# Out:
# 🌤️ SISTEMA DE EXTRACCIÓN DE DATOS METEOROLÓGICOS DIARIOS DE JALISCO
# ======================================================================
# Variables: date, p, evap, tmax, tmin
# Valores nulos (incluyendo 'NULO') se reemplazan por: NA
# Se completarán fechas faltantes con registros NA
# 🔧 Configurando entorno de Google Colab...
# ¿Deseas montar Google Drive? (s/n): s
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Google Drive montado correctamente
# 📂 Directorio de trabajo: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS
#
# 🔎 Buscando archivo de estaciones en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/estaciones.txt
# 📖 Se leyeron 275 estaciones del archivo: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/estaciones.txt
#
# 🔄 Procesando 275 estaciones...
#
# [1/275] 🔍 Procesando estación: 14001
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14001.txt
#   🏢 Estación: ACATIC (SMN) (ACATIC)
#     📊 Se extrajeron 4429 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 1973-12-31
#     ✅ Después de completar fechas: 4748 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1973-12-31', 'p': '0', 'evap': 'NA', 'tmax': '25', 'tmin': '3'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14001.csv
#   📦 Creando archivo unificado: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/datos_diarios_unidos.csv
#
# [2/275] 🔍 Procesando estación: 14002
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14002.txt
#   🏢 Estación: ACATLAN DE JUAREZ (ACATLÁN DE JUÁREZ)
#     📊 Se extrajeron 22289 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 2025-07-21
#     ✅ Después de completar fechas: 23578 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': '27', 'tmin': '6'}
#     📍 Último registro: {'date': '2025-07-21', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14002.csv
#
# [3/275] 🔍 Procesando estación: 14004
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14004.txt
#   🏢 Estación: AGOSTADERO (SAN JUAN DE LOS LAGOS)
#     📊 Se extrajeron 9876 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 1988-07-31
#     ✅ Después de completar fechas: 10074 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': '4.5', 'tmax': '27', 'tmin': '6.5'}
#     📍 Último registro: {'date': '1988-07-31', 'p': '0', 'evap': '5.19', 'tmax': '31', 'tmin': '12'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14004.csv
#
# [4/275] 🔍 Procesando estación: 14005
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14005.txt
#   🏢 Estación: AHUIJULLO (TECALITLÁN)
#     📊 Se extrajeron 8994 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 1990-04-30
#     ✅ Después de completar fechas: 10712 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1990-04-30', 'p': '0', 'evap': '6.08', 'tmax': '37', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14005.csv
#
# [5/275] 🔍 Procesando estación: 14006
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14006.txt
#   🏢 Estación: AJOJUCAR (TEOCALTICHE)
#     📊 Se extrajeron 30156 registros diarios
#     📅 Rango de fechas: 1940-07-09 a 2025-09-30
#     ✅ Después de completar fechas: 31130 registros
#     📍 Primer registro: {'date': '1940-07-09', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14006.csv
#
# [6/275] 🔍 Procesando estación: 14007
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14007.txt
#   🏢 Estación: ACIHUATL (VILLA PURIFICACIÓN)
#     📊 Se extrajeron 5026 registros diarios
#     📅 Rango de fechas: 1969-02-01 a 1999-01-08
#     ✅ Después de completar fechas: 10934 registros
#     📍 Primer registro: {'date': '1969-02-01', 'p': '0', 'evap': '2.8', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1999-01-08', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14007.csv
#
# [7/275] 🔍 Procesando estación: 14008
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14008.txt
#   🏢 Estación: AMACUECA (AMACUECA)
#     📊 Se extrajeron 10526 registros diarios
#     📅 Rango de fechas: 1962-04-11 a 1992-12-31
#     ✅ Después de completar fechas: 11223 registros
#     📍 Primer registro: {'date': '1962-04-11', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1992-12-31', 'p': '0', 'evap': '6.49', 'tmax': '29', 'tmin': '13'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14008.csv
#
# [8/275] 🔍 Procesando estación: 14009
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14009.txt
#   🏢 Estación: AMECA (AMECA)
#     📊 Se extrajeron 29640 registros diarios
#     📅 Rango de fechas: 1923-02-01 a 2025-09-30
#     ✅ Después de completar fechas: 37498 registros
#     📍 Primer registro: {'date': '1923-02-01', 'p': '0', 'evap': 'NA', 'tmax': '22.2', 'tmin': '9'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14009.csv
#
# [9/275] 🔍 Procesando estación: 14010
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14010.txt
#   🏢 Estación: ANTONIO ESCOBEDO (SMN) (SAN JUANITO DE ESCOBEDO)
#     📊 Se extrajeron 16495 registros diarios
#     📅 Rango de fechas: 1939-04-05 a 1989-02-28
#     ✅ Después de completar fechas: 18228 registros
#     📍 Primer registro: {'date': '1939-04-05', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1989-02-28', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14010.csv
#
# [10/275] 🔍 Procesando estación: 14011
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14011.txt
#   🏢 Estación: APAZULCO (LA HUERTA)
#     📊 Se extrajeron 22304 registros diarios
#     📅 Rango de fechas: 1961-07-01 a 2025-06-17
#     ✅ Después de completar fechas: 23363 registros
#     📍 Primer registro: {'date': '1961-07-01', 'p': '0', 'evap': 'NA', 'tmax': '31.5', 'tmin': '21'}
#     📍 Último registro: {'date': '2025-06-17', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14011.csv
#
# [11/275] 🔍 Procesando estación: 14012
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14012.txt
#   🏢 Estación: EL ARENAL (SMN) (EL ARENAL)
#     📊 Se extrajeron 6322 registros diarios
#     📅 Rango de fechas: 1959-10-01 a 1979-12-31
#     ✅ Después de completar fechas: 7397 registros
#     📍 Primer registro: {'date': '1959-10-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1979-12-31', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14012.csv
#
# [12/275] 🔍 Procesando estación: 14013
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14013.txt
#   🏢 Estación: ATEMAJAC DE BRIZUELA (ATEMAJAC DE BRIZUELA)
#     📊 Se extrajeron 21232 registros diarios
#     📅 Rango de fechas: 1945-01-01 a 2004-09-30
#     ✅ Después de completar fechas: 21823 registros
#     📍 Primer registro: {'date': '1945-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2004-09-30', 'p': '0', 'evap': 'NA', 'tmax': '20.5', 'tmin': '9'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14013.csv
#
# [13/275] 🔍 Procesando estación: 14014
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14014.txt
#   🏢 Estación: ATENGO (SMN) (ATENGO)
#     📊 Se extrajeron 14571 registros diarios
#     📅 Rango de fechas: 1945-07-01 a 1991-04-30
#     ✅ Después de completar fechas: 16740 registros
#     📍 Primer registro: {'date': '1945-07-01', 'p': '5.5', 'evap': 'NA', 'tmax': '25.3', 'tmin': '25'}
#     📍 Último registro: {'date': '1991-04-30', 'p': '0', 'evap': '7.23', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14014.csv
#
# [14/275] 🔍 Procesando estación: 14015
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14015.txt
#   🏢 Estación: ATENGUILLO (ATENGUILLO)
#     📊 Se extrajeron 16481 registros diarios
#     📅 Rango de fechas: 1950-10-01 a 2000-12-31
#     ✅ Después de completar fechas: 18355 registros
#     📍 Primer registro: {'date': '1950-10-01', 'p': '0', 'evap': '3.68', 'tmax': '26.8', 'tmin': '16.1'}
#     📍 Último registro: {'date': '2000-12-31', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14015.csv
#
# [15/275] 🔍 Procesando estación: 14016
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14016.txt
#   🏢 Estación: ATEQUIZA (IXTLAHUACÁN DE LOS MEMBRILLOS)
#     📊 Se extrajeron 26401 registros diarios
#     📅 Rango de fechas: 1951-01-01 a 2025-09-30
#     ✅ Después de completar fechas: 27302 registros
#     📍 Primer registro: {'date': '1951-01-01', 'p': '0', 'evap': '3', 'tmax': '24', 'tmin': '4'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14016.csv
#
# [16/275] 🔍 Procesando estación: 14017
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14017.txt
#   🏢 Estación: ATOTONILCO EL ALTO (ATOTONILCO EL ALTO)
#     📊 Se extrajeron 26760 registros diarios
#     📅 Rango de fechas: 1942-10-01 a 2024-09-02
#     ✅ Después de completar fechas: 29923 registros
#     📍 Primer registro: {'date': '1942-10-01', 'p': '3.5', 'evap': 'NA', 'tmax': '29', 'tmin': '14'}
#     📍 Último registro: {'date': '2024-09-02', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14017.csv
#
# [17/275] 🔍 Procesando estación: 14018
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14018.txt
#   🏢 Estación: ATOYAC (ATOYAC)
#     📊 Se extrajeron 28386 registros diarios
#     📅 Rango de fechas: 1943-08-01 a 2023-12-13
#     ✅ Después de completar fechas: 29355 registros
#     📍 Primer registro: {'date': '1943-08-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2023-12-13', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14018.csv
#
# [18/275] 🔍 Procesando estación: 14019
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14019.txt
#   🏢 Estación: AUTLAN (AUTLÁN DE NAVARRO)
#     📊 Se extrajeron 17516 registros diarios
#     📅 Rango de fechas: 1945-10-01 a 2000-12-31
#     ✅ Después de completar fechas: 20181 registros
#     📍 Primer registro: {'date': '1945-10-01', 'p': '5', 'evap': 'NA', 'tmax': '25', 'tmin': '22'}
#     📍 Último registro: {'date': '2000-12-31', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14019.csv
#
# [19/275] 🔍 Procesando estación: 14020
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14020.txt
#   🏢 Estación: AYO EL CHICO (AYOTLÁN)
#     📊 Se extrajeron 14148 registros diarios
#     📅 Rango de fechas: 1948-04-01 a 1990-08-31
#     ✅ Después de completar fechas: 15493 registros
#     📍 Primer registro: {'date': '1948-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1990-08-31', 'p': '0', 'evap': '1.85', 'tmax': '18', 'tmin': '4.7'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14020.csv
#
# [20/275] 🔍 Procesando estación: 14021
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14021.txt
#   🏢 Estación: AYOTITLAN (CUAUTITLÁN DE GARCÍA BARRAGÁN)
#     📊 Se extrajeron 9473 registros diarios
#     📅 Rango de fechas: 1961-07-01 a 1989-12-31
#     ✅ Después de completar fechas: 10411 registros
#     📍 Primer registro: {'date': '1961-07-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1989-12-31', 'p': '0', 'evap': 'NA', 'tmax': '20', 'tmin': '11'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14021.csv
#
# [21/275] 🔍 Procesando estación: 14022
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14022.txt
#   🏢 Estación: CLAVELLINAS (TUXPAN)
#     📊 Se extrajeron 1152 registros diarios
#     📅 Rango de fechas: 1993-01-01 a 2007-09-30
#     ✅ Después de completar fechas: 5386 registros
#     📍 Primer registro: {'date': '1993-01-01', 'p': '0', 'evap': '3.79', 'tmax': '29', 'tmin': '15'}
#     📍 Último registro: {'date': '2007-09-30', 'p': '0', 'evap': '4', 'tmax': '34', 'tmin': '21'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14022.csv
#
# [22/275] 🔍 Procesando estación: 14023
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14023.txt
#   🏢 Estación: BOLAÑOS (BOLAÑOS)
#     📊 Se extrajeron 27741 registros diarios
#     📅 Rango de fechas: 1947-02-01 a 2025-09-30
#     ✅ Después de completar fechas: 28732 registros
#     📍 Primer registro: {'date': '1947-02-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14023.csv
#
# [23/275] 🔍 Procesando estación: 14024
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14024.txt
#   🏢 Estación: CAJON DE PEÑA (TOMATLÁN)
#     📊 Se extrajeron 23399 registros diarios
#     📅 Rango de fechas: 1954-08-01 a 2025-09-30
#     ✅ Después de completar fechas: 25994 registros
#     📍 Primer registro: {'date': '1954-08-01', 'p': '1.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14024.csv
#
# [24/275] 🔍 Procesando estación: 14025
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14025.txt
#   🏢 Estación: CALERA (TEOCALTICHE)
#     📊 Se extrajeron 18362 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 2017-07-31
#     ✅ Después de completar fechas: 20666 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': '5.6', 'tmax': '27', 'tmin': '5'}
#     📍 Último registro: {'date': '2017-07-31', 'p': '0', 'evap': '7.14', 'tmax': '29', 'tmin': '11.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14025.csv
#
# [25/275] 🔍 Procesando estación: 14026
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14026.txt
#   🏢 Estación: CASA LLANTA (COLOTLÁN)
#     📊 Se extrajeron 23607 registros diarios
#     📅 Rango de fechas: 1957-07-01 a 2025-10-14
#     ✅ Después de completar fechas: 24943 registros
#     📍 Primer registro: {'date': '1957-07-01', 'p': '0', 'evap': '11.76', 'tmax': '33.5', 'tmin': '23'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14026.csv
#
# [26/275] 🔍 Procesando estación: 14027
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14027.txt
#   🏢 Estación: CASIMIRO CASTILLO (CASIMIRO CASTILLO)
#     📊 Se extrajeron 15680 registros diarios
#     📅 Rango de fechas: 1953-10-08 a 2003-12-20
#     ✅ Después de completar fechas: 18336 registros
#     📍 Primer registro: {'date': '1953-10-08', 'p': '14', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2003-12-20', 'p': '0', 'evap': '3.47', 'tmax': '35', 'tmin': '10.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14027.csv
#
# [27/275] 🔍 Procesando estación: 14028
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14028.txt
#   🏢 Estación: CIHUATLAN (DGE) (CIHUATLÁN)
#     📊 Se extrajeron 26576 registros diarios
#     📅 Rango de fechas: 1946-12-01 a 2025-10-16
#     ✅ Después de completar fechas: 28810 registros
#     📍 Primer registro: {'date': '1946-12-01', 'p': '0', 'evap': 'NA', 'tmax': '31.5', 'tmin': '20'}
#     📍 Último registro: {'date': '2025-10-16', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14028.csv
#
# [28/275] 🔍 Procesando estación: 14029
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14029.txt
#   🏢 Estación: CONCEPCION DE BUENOS AIRES (CONCEPCIÓN DE BUENOS AIRES)
#     📊 Se extrajeron 18507 registros diarios
#     📅 Rango de fechas: 1970-01-01 a 2024-06-30
#     ✅ Después de completar fechas: 19905 registros
#     📍 Primer registro: {'date': '1970-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2024-06-30', 'p': '4.1', 'evap': '2.13', 'tmax': '25', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14029.csv
#
# [29/275] 🔍 Procesando estación: 14030
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14030.txt
#   🏢 Estación: CIUDAD GUZMAN (OBS) (ZAPOTLÁN EL GRANDE)
#     📊 Se extrajeron 32678 registros diarios
#     📅 Rango de fechas: 1897-01-01 a 2025-09-30
#     ✅ Después de completar fechas: 47024 registros
#     📍 Primer registro: {'date': '1897-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14030.csv
#
# [30/275] 🔍 Procesando estación: 14031
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14031.txt
#   🏢 Estación: CIUDAD VENUSTIANO CARRANZA (SAN GABRIEL)
#     📊 Se extrajeron 15333 registros diarios
#     📅 Rango de fechas: 1946-06-01 a 1991-06-30
#     ✅ Después de completar fechas: 16466 registros
#     📍 Primer registro: {'date': '1946-06-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1991-06-30', 'p': '27', 'evap': 'NA', 'tmax': '26', 'tmin': '18.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14031.csv
#
# [31/275] 🔍 Procesando estación: 14032
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14032.txt
#   🏢 Estación: COLOTLAN (OBS) (COLOTLÁN)
#     📊 Se extrajeron 15038 registros diarios
#     📅 Rango de fechas: 1966-08-01 a 2025-09-30
#     ✅ Después de completar fechas: 21611 registros
#     📍 Primer registro: {'date': '1966-08-01', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14032.csv
#
# [32/275] 🔍 Procesando estación: 14033
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14033.txt
#   🏢 Estación: COMANJA DE CORONA (LAGOS DE MORENO)
#     📊 Se extrajeron 17755 registros diarios
#     📅 Rango de fechas: 1963-02-14 a 2023-06-30
#     ✅ Después de completar fechas: 22052 registros
#     📍 Primer registro: {'date': '1963-02-14', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '2'}
#     📍 Último registro: {'date': '2023-06-30', 'p': '0', 'evap': '8.08', 'tmax': '27', 'tmin': '14'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14033.csv
#
# [33/275] 🔍 Procesando estación: 14034
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14034.txt
#   🏢 Estación: CONTLA (TAMAZULA DE GORDIANO)
#     📊 Se extrajeron 19145 registros diarios
#     📅 Rango de fechas: 1970-12-01 a 2023-10-31
#     ✅ Después de completar fechas: 19328 registros
#     📍 Primer registro: {'date': '1970-12-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2023-10-31', 'p': '0', 'evap': '4', 'tmax': '30', 'tmin': '17'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14034.csv
#
# [34/275] 🔍 Procesando estación: 14035
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14035.txt
#   🏢 Estación: CORRINCHIS II (MASCOTA)
#     📊 Se extrajeron 22028 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 2025-10-14
#     ✅ Después de completar fechas: 23663 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': '3', 'tmax': '25', 'tmin': '6.5'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14035.csv
#
# [35/275] 🔍 Procesando estación: 14036
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14036.txt
#   🏢 Estación: CUAUTITLAN (CUAUTITLÁN DE GARCÍA BARRAGÁN)
#     📊 Se extrajeron 23908 registros diarios
#     📅 Rango de fechas: 1958-06-07 a 2024-09-19
#     ✅ Después de completar fechas: 24212 registros
#     📍 Primer registro: {'date': '1958-06-07', 'p': '40.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2024-09-19', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14036.csv
#
# [36/275] 🔍 Procesando estación: 14037
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14037.txt
#   🏢 Estación: PRESA ACHIMEC (HUEJÚCAR)
#     📊 Se extrajeron 14478 registros diarios
#     📅 Rango de fechas: 1969-01-01 a 2025-10-10
#     ✅ Después de completar fechas: 20737 registros
#     📍 Primer registro: {'date': '1969-01-01', 'p': '0.8', 'evap': 'NA', 'tmax': '23', 'tmin': '9'}
#     📍 Último registro: {'date': '2025-10-10', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14037.csv
#
# [37/275] 🔍 Procesando estación: 14038
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14038.txt
#   🏢 Estación: CUIXTLA (SAN CRISTÓBAL DE LA BARRANCA)
#     📊 Se extrajeron 25602 registros diarios
#     📅 Rango de fechas: 1954-06-12 a 2025-09-30
#     ✅ Después de completar fechas: 26044 registros
#     📍 Primer registro: {'date': '1954-06-12', 'p': '0', 'evap': '8.47', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14038.csv
#
# [38/275] 🔍 Procesando estación: 14039
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14039.txt
#   🏢 Estación: CUQUIO (CUQUÍO)
#     📊 Se extrajeron 28196 registros diarios
#     📅 Rango de fechas: 1943-06-01 a 2024-04-30
#     ✅ Después de completar fechas: 29555 registros
#     📍 Primer registro: {'date': '1943-06-01', 'p': '0.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2024-04-30', 'p': '0', 'evap': '7.35', 'tmax': '32', 'tmin': '10'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14039.csv
#
# [39/275] 🔍 Procesando estación: 14040
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14040.txt
#   🏢 Estación: CHAPALA (CHAPALA)
#     📊 Se extrajeron 32711 registros diarios
#     📅 Rango de fechas: 1934-04-01 a 2025-10-14
#     ✅ Después de completar fechas: 33435 registros
#     📍 Primer registro: {'date': '1934-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14040.csv
#
# [40/275] 🔍 Procesando estación: 14041
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14041.txt
#   🏢 Estación: CHIQUILISTLAN (CHIQUILISTLÁN)
#     📊 Se extrajeron 7027 registros diarios
#     📅 Rango de fechas: 1964-12-21 a 1989-05-31
#     ✅ Después de completar fechas: 8928 registros
#     📍 Primer registro: {'date': '1964-12-21', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1989-05-31', 'p': '0', 'evap': '3.69', 'tmax': '31', 'tmin': '10'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14041.csv
#
# [41/275] 🔍 Procesando estación: 14042
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14042.txt
#   🏢 Estación: CUITZMALA (LA HUERTA)
#     📊 Se extrajeron 12080 registros diarios
#     📅 Rango de fechas: 1955-06-06 a 1995-12-31
#     ✅ Después de completar fechas: 14819 registros
#     📍 Primer registro: {'date': '1955-06-06', 'p': '8.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1995-12-31', 'p': '0', 'evap': 'NA', 'tmax': '31', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14042.csv
#
# [42/275] 🔍 Procesando estación: 14043
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14043.txt
#   🏢 Estación: EJUTLA (EJUTLA)
#     📊 Se extrajeron 22192 registros diarios
#     📅 Rango de fechas: 1940-07-14 a 2008-06-30
#     ✅ Después de completar fechas: 24824 registros
#     📍 Primer registro: {'date': '1940-07-14', 'p': '1.8', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2008-06-30', 'p': '0', 'evap': '3.51', 'tmax': '29', 'tmin': '15'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14043.csv
#
# [43/275] 🔍 Procesando estación: 14044
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14044.txt
#   🏢 Estación: EL BRAMADOR (TALPA DE ALLENDE)
#     📊 Se extrajeron 22013 registros diarios
#     📅 Rango de fechas: 1959-08-01 a 2024-10-25
#     ✅ Después de completar fechas: 23828 registros
#     📍 Primer registro: {'date': '1959-08-01', 'p': '16.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2024-10-25', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14044.csv
#
# [44/275] 🔍 Procesando estación: 14045
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14045.txt
#   🏢 Estación: CABRITO (ARANDAS)
#     📊 Se extrajeron 3730 registros diarios
#     📅 Rango de fechas: 1969-01-01 a 1979-05-31
#     ✅ Después de completar fechas: 3803 registros
#     📍 Primer registro: {'date': '1969-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1979-05-31', 'p': '9', 'evap': '4.3', 'tmax': '37', 'tmin': '21.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14045.csv
#
# [45/275] 🔍 Procesando estación: 14046
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14046.txt
#   🏢 Estación: EL CHANTE (AUTLÁN DE NAVARRO)
#     📊 Se extrajeron 17244 registros diarios
#     📅 Rango de fechas: 1969-11-07 a 2020-06-30
#     ✅ Después de completar fechas: 18499 registros
#     📍 Primer registro: {'date': '1969-11-07', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2020-06-30', 'p': '0', 'evap': '6.33', 'tmax': '30', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14046.csv
#
# [46/275] 🔍 Procesando estación: 14047
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14047.txt
#   🏢 Estación: EL FUERTE (OCOTLÁN)
#     📊 Se extrajeron 22079 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 2025-09-30
#     ✅ Después de completar fechas: 23649 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': '4.4', 'tmax': '25', 'tmin': '8'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14047.csv
#
# [47/275] 🔍 Procesando estación: 14048
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14048.txt
#   🏢 Estación: EL CHIFLON (CIHUATLÁN)
#     📊 Se extrajeron 23476 registros diarios
#     📅 Rango de fechas: 1954-07-01 a 2025-09-30
#     ✅ Después de completar fechas: 26025 registros
#     📍 Primer registro: {'date': '1954-07-01', 'p': '10.5', 'evap': '3.84', 'tmax': '34', 'tmin': '23'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14048.csv
#
# [48/275] 🔍 Procesando estación: 14049
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14049.txt
#   🏢 Estación: GARGANTILLO (TOMATLÁN)
#     📊 Se extrajeron 9465 registros diarios
#     📅 Rango de fechas: 1955-08-01 a 1988-05-31
#     ✅ Después de completar fechas: 11993 registros
#     📍 Primer registro: {'date': '1955-08-01', 'p': '26.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1988-05-31', 'p': '0', 'evap': '5.37', 'tmax': '32', 'tmin': '16'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14049.csv
#
# [49/275] 🔍 Procesando estación: 14050
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14050.txt
#   🏢 Estación: EL GRULLO (EL GRULLO)
#     📊 Se extrajeron 16966 registros diarios
#     📅 Rango de fechas: 1939-01-01 a 1991-06-30
#     ✅ Después de completar fechas: 19174 registros
#     📍 Primer registro: {'date': '1939-01-01', 'p': '0', 'evap': 'NA', 'tmax': '31', 'tmin': '10.5'}
#     📍 Último registro: {'date': '1991-06-30', 'p': '1', 'evap': '3.42', 'tmax': '28', 'tmin': '19.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14050.csv
#
# [50/275] 🔍 Procesando estación: 14051
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14051.txt
#   🏢 Estación: EL LIMON (EL LIMÓN)
#     📊 Se extrajeron 10677 registros diarios
#     📅 Rango de fechas: 1944-12-01 a 1984-06-30
#     ✅ Después de completar fechas: 14457 registros
#     📍 Primer registro: {'date': '1944-12-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1984-06-30', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14051.csv
#
# [51/275] 🔍 Procesando estación: 14052
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14052.txt
#   🏢 Estación: EL NOGAL (TAPALPA)
#     📊 Se extrajeron 25611 registros diarios
#     📅 Rango de fechas: 1946-03-01 a 2019-12-31
#     ✅ Después de completar fechas: 26969 registros
#     📍 Primer registro: {'date': '1946-03-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2019-12-31', 'p': '0', 'evap': '4.1', 'tmax': '27', 'tmin': '2'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14052.csv
#
# [52/275] 🔍 Procesando estación: 14053
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14053.txt
#   🏢 Estación: EL PINITO (HUEJUQUILLA EL ALTO)
#     📊 Se extrajeron 21032 registros diarios
#     📅 Rango de fechas: 1964-08-01 a 2025-09-29
#     ✅ Después de completar fechas: 22340 registros
#     📍 Primer registro: {'date': '1964-08-01', 'p': '2.5', 'evap': '4.3', 'tmax': '26.5', 'tmin': '12'}
#     📍 Último registro: {'date': '2025-09-29', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14053.csv
#
# [53/275] 🔍 Procesando estación: 14054
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14054.txt
#   🏢 Estación: EL PUESTO (LAGOS DE MORENO)
#     📊 Se extrajeron 18874 registros diarios
#     📅 Rango de fechas: 1965-09-02 a 2023-07-31
#     ✅ Después de completar fechas: 21152 registros
#     📍 Primer registro: {'date': '1965-09-02', 'p': '3.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2023-07-31', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '19'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14054.csv
#
# [54/275] 🔍 Procesando estación: 14055
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14055.txt
#   🏢 Estación: INGENIO EL REFUGIO (TALA)
#     📊 Se extrajeron 4207 registros diarios
#     📅 Rango de fechas: 1958-06-17 a 1971-12-31
#     ✅ Después de completar fechas: 4946 registros
#     📍 Primer registro: {'date': '1958-06-17', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1971-12-31', 'p': '0', 'evap': '3.8', 'tmax': '29.5', 'tmin': '6'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14055.csv
#
# [55/275] 🔍 Procesando estación: 14056
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14056.txt
#   🏢 Estación: EL SALITRE (SAN MARTÍN HIDALGO)
#     📊 Se extrajeron 20484 registros diarios
#     📅 Rango de fechas: 1961-01-01 a 2025-09-30
#     ✅ Después de completar fechas: 23649 registros
#     📍 Primer registro: {'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14056.csv
#
# [56/275] 🔍 Procesando estación: 14057
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14057.txt
#   🏢 Estación: EL SALTO (EL SALTO)
#     📊 Se extrajeron 13952 registros diarios
#     📅 Rango de fechas: 1948-01-01 a 1991-02-28
#     ✅ Después de completar fechas: 15765 registros
#     📍 Primer registro: {'date': '1948-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '1991-02-28', 'p': '0', 'evap': '3.06', 'tmax': '33.5', 'tmin': '12'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14057.csv
#
# [57/275] 🔍 Procesando estación: 14058
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14058.txt
#   🏢 Estación: EL TECUAN (ENCARNACIÓN DE DÍAZ)
#     📊 Se extrajeron 7122 registros diarios
#     📅 Rango de fechas: 1970-08-01 a 1990-06-30
#     ✅ Después de completar fechas: 7274 registros
#     📍 Primer registro: {'date': '1970-08-01', 'p': '0', 'evap': '4.4', 'tmax': '28', 'tmin': '11'}
#     📍 Último registro: {'date': '1990-06-30', 'p': '0', 'evap': '5.77', 'tmax': '28', 'tmin': '14'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14058.csv
#
# [58/275] 🔍 Procesando estación: 14059
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14059.txt
#   🏢 Estación: EL TUITO (CABO CORRIENTES)
#     📊 Se extrajeron 21424 registros diarios
#     📅 Rango de fechas: 1950-10-01 a 2025-09-30
#     ✅ Después de completar fechas: 27394 registros
#     📍 Primer registro: {'date': '1950-10-01', 'p': '8.9', 'evap': 'NA', 'tmax': '38', 'tmin': '14.5'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14059.csv
#
# [59/275] 🔍 Procesando estación: 14060
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14060.txt
#   🏢 Estación: EL TULE (ARANDAS)
#     📊 Se extrajeron 17216 registros diarios
#     📅 Rango de fechas: 1962-06-21 a 2025-10-14
#     ✅ Después de completar fechas: 23127 registros
#     📍 Primer registro: {'date': '1962-06-21', 'p': '5.8', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14060.csv
#
# [60/275] 🔍 Procesando estación: 14062
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14062.txt
#   🏢 Estación: ENCARNACION DE DIAZ (ENCARNACIÓN DE DÍAZ)
#     📊 Se extrajeron 21029 registros diarios
#     📅 Rango de fechas: 1939-01-01 a 1999-01-31
#     ✅ Después de completar fechas: 21946 registros
#     📍 Primer registro: {'date': '1939-01-01', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '11'}
#     📍 Último registro: {'date': '1999-01-31', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14062.csv
#
# [61/275] 🔍 Procesando estación: 14063
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14063.txt
#   🏢 Estación: ETZATLAN (SMN) (ETZATLÁN)
#     📊 Se extrajeron 18868 registros diarios
#     📅 Rango de fechas: 1948-05-01 a 2021-09-30
#     ✅ Después de completar fechas: 26816 registros
#     📍 Primer registro: {'date': '1948-05-01', 'p': '0', 'evap': 'NA', 'tmax': '33', 'tmin': '14'}
#     📍 Último registro: {'date': '2021-09-30', 'p': '0', 'evap': 'NA', 'tmax': '32', 'tmin': '11'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14063.csv
#
# [62/275] 🔍 Procesando estación: 14064
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14064.txt
#   🏢 Estación: EX HACIENDA SAN DIEGO (COCULA)
#     📊 Se extrajeron 13713 registros diarios
#     📅 Rango de fechas: 1947-06-12 a 1986-08-31
#     ✅ Después de completar fechas: 14326 registros
#     📍 Primer registro: {'date': '1947-06-12', 'p': '0', 'evap': 'NA', 'tmax': '27', 'tmin': '21'}
#     📍 Último registro: {'date': '1986-08-31', 'p': '0', 'evap': 'NA', 'tmax': '24', 'tmin': '11.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14064.csv
#
# [63/275] 🔍 Procesando estación: 14065
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14065.txt
#   🏢 Estación: GUADALAJARA (OBS) (GUADALAJARA)
#     📊 Se extrajeron 23891 registros diarios
#     📅 Rango de fechas: 1882-04-01 a 2025-09-25
#     ✅ Después de completar fechas: 52408 registros
#     📍 Primer registro: {'date': '1882-04-01', 'p': '3', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-25', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14065.csv
#
# [64/275] 🔍 Procesando estación: 14066
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14066.txt
#   🏢 Estación: GUADALAJARA (DGE) (GUADALAJARA)
#     📊 Se extrajeron 31247 registros diarios
#     📅 Rango de fechas: 1930-09-01 a 2025-09-26
#     ✅ Después de completar fechas: 34725 registros
#     📍 Primer registro: {'date': '1930-09-01', 'p': '4', 'evap': 'NA', 'tmax': '28', 'tmin': '16'}
#     📍 Último registro: {'date': '2025-09-26', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14066.csv
#
# [65/275] 🔍 Procesando estación: 14067
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14067.txt
#   🏢 Estación: HIGUERA BLANCA (TOMATLÁN)
#     📊 Se extrajeron 23648 registros diarios
#     📅 Rango de fechas: 1955-04-01 a 2025-10-14
#     ✅ Después de completar fechas: 25765 registros
#     📍 Primer registro: {'date': '1955-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14067.csv
#
# [66/275] 🔍 Procesando estación: 14068
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14068.txt
#   🏢 Estación: HOSTOTIPAQUILLO (HOSTOTIPAQUILLO)
#     📊 Se extrajeron 28097 registros diarios
#     📅 Rango de fechas: 1939-01-01 a 2021-04-30
#     ✅ Después de completar fechas: 30071 registros
#     📍 Primer registro: {'date': '1939-01-01', 'p': 'NA', 'evap': 'NA', 'tmax': '27.1', 'tmin': '11'}
#     📍 Último registro: {'date': '2021-04-30', 'p': '0', 'evap': '8.12', 'tmax': '35', 'tmin': '12'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14068.csv
#
# [67/275] 🔍 Procesando estación: 14069
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14069.txt
#   🏢 Estación: HUEJUCAR (OBS) (HUEJÚCAR)
#     📊 Se extrajeron 21357 registros diarios
#     📅 Rango de fechas: 1947-02-01 a 2021-12-31
#     ✅ Después de completar fechas: 27363 registros
#     📍 Primer registro: {'date': '1947-02-01', 'p': '0', 'evap': 'NA', 'tmax': '21.5', 'tmin': '9'}
#     📍 Último registro: {'date': '2021-12-31', 'p': '0', 'evap': '2.85', 'tmax': '23', 'tmin': '0'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14069.csv
#
# [68/275] 🔍 Procesando estación: 14070
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14070.txt
#   🏢 Estación: HUASCATO (DEGOLLADO)
#     📊 Se extrajeron 21246 registros diarios
#     📅 Rango de fechas: 1964-01-01 a 2025-09-30
#     ✅ Después de completar fechas: 22554 registros
#     📍 Primer registro: {'date': '1964-01-01', 'p': '0', 'evap': '4.2', 'tmax': '20.5', 'tmin': '3'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14070.csv
#
# [69/275] 🔍 Procesando estación: 14071
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14071.txt
#   🏢 Estación: HUEJUQUILLA EL ALTO (DGE) (HUEJUQUILLA EL ALTO)
#     📊 Se extrajeron 10871 registros diarios
#     📅 Rango de fechas: 1986-01-01 a 2024-02-21
#     ✅ Después de completar fechas: 13931 registros
#     📍 Primer registro: {'date': '1986-01-01', 'p': '0', 'evap': '4.4', 'tmax': '25', 'tmin': '7'}
#     📍 Último registro: {'date': '2024-02-21', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14071.csv
#
# [70/275] 🔍 Procesando estación: 14072
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14072.txt
#   🏢 Estación: HUERTA VIEJA (IXTLAHUACÁN DE LOS MEMBRILLOS)
#     📊 Se extrajeron 26198 registros diarios
#     📅 Rango de fechas: 1950-10-01 a 2025-10-14
#     ✅ Después de completar fechas: 27408 registros
#     📍 Primer registro: {'date': '1950-10-01', 'p': '3.1', 'evap': '5.39', 'tmax': '26', 'tmin': '17'}
#     📍 Último registro: {'date': '2025-10-14', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14072.csv
#
# [71/275] 🔍 Procesando estación: 14073
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14073.txt
#   🏢 Estación: IXTLAHUACAN DEL RIO (IXTLAHUACÁN DEL RÍO)
#     📊 Se extrajeron 20627 registros diarios
#     📅 Rango de fechas: 1943-06-01 a 2005-02-28
#     ✅ Después de completar fechas: 22554 registros
#     📍 Primer registro: {'date': '1943-06-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2005-02-28', 'p': '0', 'evap': 'NA', 'tmax': '34', 'tmin': '10'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14073.csv
#
# [72/275] 🔍 Procesando estación: 14074
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14074.txt
#   🏢 Estación: JALOSTOTITLAN (JALOSTOTITLÁN)
#     📊 Se extrajeron 22926 registros diarios
#     📅 Rango de fechas: 1941-11-01 a 2009-09-30
#     ✅ Después de completar fechas: 24806 registros
#     📍 Primer registro: {'date': '1941-11-01', 'p': '11.1', 'evap': 'NA', 'tmax': '27', 'tmin': '16'}
#     📍 Último registro: {'date': '2009-09-30', 'p': '0', 'evap': '3.01', 'tmax': '27', 'tmin': '13.5'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14074.csv
#
# [73/275] 🔍 Procesando estación: 14075
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14075.txt
#   🏢 Estación: JAMAY (JAMAY)
#     📊 Se extrajeron 24172 registros diarios
#     📅 Rango de fechas: 1948-02-01 a 2025-09-30
#     ✅ Después de completar fechas: 28367 registros
#     📍 Primer registro: {'date': '1948-02-01', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14075.csv
#
# [74/275] 🔍 Procesando estación: 14076
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14076.txt
#   🏢 Estación: JESUS MARIA (JESÚS MARÍA)
#     📊 Se extrajeron 27690 registros diarios
#     📅 Rango de fechas: 1944-02-01 a 2024-01-31
#     ✅ Después de completar fechas: 29220 registros
#     📍 Primer registro: {'date': '1944-02-01', 'p': '0', 'evap': 'NA', 'tmax': '23', 'tmin': '8'}
#     📍 Último registro: {'date': '2024-01-31', 'p': '0', 'evap': '1.57', 'tmax': '17.5', 'tmin': '7'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14076.csv
#
# [75/275] 🔍 Procesando estación: 14077
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14077.txt
#   🏢 Estación: JOCOTEPEC (JOCOTEPEC)
#     📊 Se extrajeron 18879 registros diarios
#     📅 Rango de fechas: 1946-07-01 a 2007-01-06
#     ✅ Después de completar fechas: 22105 registros
#     📍 Primer registro: {'date': '1946-07-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2007-01-06', 'p': '0', 'evap': '3.79', 'tmax': '23', 'tmin': '6'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14077.csv
#
# [76/275] 🔍 Procesando estación: 14078
# ...
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14396.csv
#
# [275/275] 🔍 Procesando estación: 14397
#   📥 Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14397.txt
#   🏢 Estación: PRESA CALDERON (ZAPOTLANEJO)
#     📊 Se extrajeron 12045 registros diarios
#     📅 Rango de fechas: 1991-08-22 a 2025-09-30
#     ✅ Después de completar fechas: 12459 registros
#     📍 Primer registro: {'date': '1991-08-22', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#     📍 Último registro: {'date': '2025-09-30', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}
#   💾 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14397.csv
#
# 🎉 ¡PROCESO COMPLETADO!
# ✅ Estaciones con datos extraídos: 275/275
# 📂 Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS
#
# 📊 Reporte generado: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/reporte_estaciones.csv
# 📈 Total de estaciones con datos: 275
#   📍 14001: 4748 registros
#   📍 14002: 23578 registros
#   📍 14004: 10074 registros
#   📍 14005: 10712 registros
#   📍 14006: 31130 registros
#   📍 14007: 10934 registros
#   📍 14008: 11223 registros
#   📍 14009: 37498 registros
#   📍 14010: 18228 registros
#   📍 14011: 23363 registros
#   📍 14012: 7397 registros
#   📍 14013: 21823 registros
#   📍 14014: 16740 registros
#   📍 14015: 18355 registros
#   📍 14016: 27302 registros
#   📍 14017: 29923 registros
#   📍 14018: 29355 registros
#   📍 14019: 20181 registros
#   📍 14020: 15493 registros
#   📍 14021: 10411 registros
#   📍 14022: 5386 registros
#   📍 14023: 28732 registros
#   📍 14024: 25994 registros
#   📍 14025: 20666 registros
#   📍 14026: 24943 registros
#   📍 14027: 18336 registros
#   📍 14028: 28810 registros
#   📍 14029: 19905 registros
#   📍 14030: 47024 registros
#   📍 14031: 16466 registros
#   📍 14032: 21611 registros
#   📍 14033: 22052 registros
#   📍 14034: 19328 registros
#   📍 14035: 23663 registros
#   📍 14036: 24212 registros
#   📍 14037: 20737 registros
#   📍 14038: 26044 registros
#   📍 14039: 29555 registros
#   📍 14040: 33435 registros
#   📍 14041: 8928 registros
#   📍 14042: 14819 registros
#   📍 14043: 24824 registros
#   📍 14044: 23828 registros
#   📍 14045: 3803 registros
#   📍 14046: 18499 registros
#   📍 14047: 23649 registros
#   📍 14048: 26025 registros
#   📍 14049: 11993 registros
#   📍 14050: 19174 registros
#   📍 14051: 14457 registros
#   📍 14052: 26969 registros
#   📍 14053: 22340 registros
#   📍 14054: 21152 registros
#   📍 14055: 4946 registros
#   📍 14056: 23649 registros
#   📍 14057: 15765 registros
#   📍 14058: 7274 registros
#   📍 14059: 27394 registros
#   📍 14060: 23127 registros
#   📍 14062: 21946 registros
#   📍 14063: 26816 registros
#   📍 14064: 14326 registros
#   📍 14065: 52408 registros
#   📍 14066: 34725 registros
#   📍 14067: 25765 registros
#   📍 14068: 30071 registros
#   📍 14069: 27363 registros
#   📍 14070: 22554 registros
#   📍 14071: 13931 registros
#   📍 14072: 27408 registros
#   📍 14073: 22554 registros
#   📍 14074: 24806 registros
#   📍 14075: 28367 registros
#   📍 14076: 29220 registros
#   📍 14077: 22105 registros
#   📍 14078: 27788 registros
#   📍 14079: 8981 registros
#   📍 14080: 27881 registros
#   📍 14081: 27881 registros
#   📍 14082: 5478 registros
#   📍 14083: 24620 registros
#   📍 14084: 30603 registros
#   📍 14085: 24868 registros
#   📍 14086: 24138 registros
#   📍 14087: 23512 registros
#   📍 14088: 3012 registros
#   📍 14089: 25852 registros
#   📍 14090: 20434 registros
#   📍 14091: 10987 registros
#   📍 14092: 4533 registros
#   📍 14093: 28460 registros
#   📍 14094: 11040 registros
#   📍 14095: 9526 registros
#   📍 14096: 37379 registros
#   📍 14097: 4231 registros
#   📍 14098: 12388 registros
#   📍 14099: 28156 registros
#   📍 14100: 29434 registros
#   📍 14101: 22401 registros
#   📍 14102: 14371 registros
#   📍 14103: 15820 registros
#   📍 14104: 28155 registros
#   📍 14105: 10411 registros
#   📍 14106: 17739 registros
#   📍 14107: 14060 registros
#   📍 14108: 13688 registros
#   📍 14109: 9552 registros
#   📍 14110: 12965 registros
#   📍 14111: 31274 registros
#   📍 14112: 6591 registros
#   📍 14113: 28930 registros
#   📍 14114: 23893 registros
#   📍 14115: 11314 registros
#   📍 14116: 22776 registros
#   📍 14117: 25111 registros
#   📍 14118: 29599 registros
#   📍 14119: 23637 registros
#   📍 14120: 2830 registros
#   📍 14121: 15340 registros
#   📍 14122: 30339 registros
#   📍 14123: 29525 registros
#   📍 14124: 7823 registros
#   📍 14125: 29752 registros
#   📍 14126: 17224 registros
#   📍 14127: 10289 registros
#   📍 14128: 18842 registros
#   📍 14129: 22767 registros
#   📍 14130: 10773 registros
#   📍 14131: 22221 registros
#   📍 14132: 30194 registros
#   📍 14133: 14276 registros
#   📍 14134: 9086 registros
#   📍 14135: 14701 registros
#   📍 14136: 25743 registros
#   📍 14138: 9984 registros
#   📍 14139: 28429 registros
#   📍 14140: 24015 registros
#   📍 14141: 37136 registros
#   📍 14142: 37195 registros
#   📍 14143: 30346 registros
#   📍 14144: 24929 registros
#   📍 14145: 31152 registros
#   📍 14146: 23141 registros
#   📍 14147: 17167 registros
#   📍 14148: 16540 registros
#   📍 14149: 20849 registros
#   📍 14151: 14428 registros
#   📍 14152: 23985 registros
#   📍 14153: 21185 registros
#   📍 14154: 30193 registros
#   📍 14155: 23256 registros
#   📍 14156: 28961 registros
#   📍 14157: 23041 registros
#   📍 14158: 29159 registros
#   📍 14159: 17167 registros
#   📍 14160: 27252 registros
#   📍 14161: 2708 registros
#   📍 14162: 15187 registros
#   📍 14163: 10257 registros
#   📍 14164: 24940 registros
#   📍 14165: 29434 registros
#   📍 14166: 16247 registros
#   📍 14167: 30271 registros
#   📍 14168: 28732 registros
#   📍 14169: 30787 registros
#   📍 14170: 15767 registros
#   📍 14171: 31565 registros
#   📍 14173: 15737 registros
#   📍 14174: 9131 registros
#   📍 14175: 17897 registros
#   📍 14176: 14745 registros
#   📍 14177: 13950 registros
#   📍 14178: 16587 registros
#   📍 14179: 13239 registros
#   📍 14180: 28991 registros
#   📍 14182: 5903 registros
#   📍 14183: 15432 registros
#   📍 14184: 10623 registros
#   📍 14185: 10957 registros
#   📍 14186: 10837 registros
#   📍 14187: 23070 registros
#   📍 14188: 7427 registros
#   📍 14189: 19258 registros
#   📍 14190: 6575 registros
#   📍 14191: 10470 registros
#   📍 14192: 7458 registros
#   📍 14195: 12631 registros
#   📍 14196: 9466 registros
#   📍 14197: 7600 registros
#   📍 14198: 4535 registros
#   📍 14199: 4475 registros
#   📍 14200: 4470 registros
#   📍 14202: 2557 registros
#   📍 14266: 23649 registros
#   📍 14269: 30712 registros
#   📍 14271: 4637 registros
#   📍 14276: 16786 registros
#   📍 14277: 3226 registros
#   📍 14278: 4748 registros
#   📍 14279: 9861 registros
#   📍 14280: 17805 registros
#   📍 14281: 3438 registros
#   📍 14287: 6117 registros
#   📍 14292: 3744 registros
#   📍 14294: 13870 registros
#   📍 14295: 2070 registros
#   📍 14296: 5448 registros
#   📍 14297: 13939 registros
#   📍 14301: 10349 registros
#   📍 14302: 1230 registros
#   📍 14304: 11195 registros
#   📍 14306: 16881 registros
#   📍 14307: 5682 registros
#   📍 14308: 5813 registros
#   📍 14309: 5418 registros
#   📍 14310: 4332 registros
#   📍 14311: 16432 registros
#   📍 14312: 4291 registros
#   📍 14313: 2039 registros
#   📍 14314: 3487 registros
#   📍 14315: 11169 registros
#   📍 14316: 4293 registros
#   📍 14317: 12346 registros
#   📍 14318: 1882 registros
#   📍 14319: 10074 registros
#   📍 14320: 16538 registros
#   📍 14322: 7305 registros
#   📍 14323: 14853 registros
#   📍 14324: 16785 registros
#   📍 14325: 4383 registros
#   📍 14326: 16216 registros
#   📍 14327: 4352 registros
#   📍 14329: 17362 registros
#   📍 14330: 4286 registros
#   📍 14331: 17027 registros
#   📍 14333: 3934 registros
#   📍 14336: 15919 registros
#   📍 14337: 16532 registros
#   📍 14338: 6848 registros
#   📍 14339: 16558 registros
#   📍 14340: 2996 registros
#   📍 14342: 1186 registros
#   📍 14343: 17001 registros
#   📍 14344: 2991 registros
#   📍 14345: 10239 registros
#   📍 14346: 16325 registros
#   📍 14347: 3840 registros
#   📍 14348: 15942 registros
#   📍 14349: 16542 registros
#   📍 14350: 15918 registros
#   📍 14351: 21093 registros
#   📍 14352: 14336 registros
#   📍 14355: 16176 registros
#   📍 14356: 2718 registros
#   📍 14360: 5175 registros
#   📍 14362: 3195 registros
#   📍 14363: 2757 registros
#   📍 14365: 2502 registros
#   📍 14367: 14648 registros
#   📍 14368: 15976 registros
#   📍 14369: 16163 registros
#   📍 14373: 5844 registros
#   📍 14376: 731 registros
#   📍 14377: 516 registros
#   📍 14379: 15979 registros
#   📍 14380: 761 registros
#   📍 14386: 12706 registros
#   📍 14387: 4079 registros
#   📍 14388: 2247 registros
#   📍 14390: 14700 registros
#   📍 14391: 12845 registros
#   📍 14392: 13040 registros
#   📍 14395: 7244 registros
#   📍 14396: 12541 registros
#   📍 14397: 12459 registros
#
# 📊 RESUMEN ESTADÍSTICO
# ========================================
# Total de registros: 4626239
# Total de estaciones: 275
# Rango de fechas: 1882-04-01 a 2025-10-16
#
# P:
#   Registros válidos: 3938042
#   Promedio: 2.37
#   Mínimo: 0.00
#   Máximo: 475.80
#
# EVAP:
#   Registros válidos: 2673973
#   Promedio: 5.09
#   Mínimo: 0.01
#   Máximo: 24.48
#
# TMAX:
#   Registros válidos: 3596650
#   Promedio: 28.92
#   Mínimo: 1.00
#   Máximo: 50.00
#
# TMIN:
#   Registros válidos: 3596650
#   Promedio: 12.19
#   Mínimo: -16.00
#   Máximo: 36.00
#
# 📥 DESCARGAR RESULTADOS
# ========================================
# Archivos disponibles para descargar:
#   1. diarios_14001.csv
#   2. datos_diarios_unidos.csv
#   3. diarios_14002.csv
#   4. diarios_14004.csv
#   5. diarios_14005.csv
#   6. diarios_14006.csv
#   7. diarios_14007.csv
#   8. diarios_14008.csv
#   9. diarios_14009.csv
#   10. diarios_14010.csv
#   11. diarios_14011.csv
#   12. diarios_14012.csv
#   13. diarios_14013.csv
#   14. diarios_14014.csv
#   15. diarios_14015.csv
#   16. diarios_14016.csv
#   17. diarios_14017.csv
#   18. diarios_14018.csv
#   19. diarios_14019.csv
#   20. diarios_14020.csv
#   21. diarios_14021.csv
#   22. diarios_14022.csv
#   23. diarios_14023.csv
#   24. diarios_14024.csv
#   25. diarios_14025.csv
#   26. diarios_14026.csv
#   27. diarios_14027.csv
#   28. diarios_14028.csv
#   29. diarios_14029.csv
#   30. diarios_14030.csv
#   31. diarios_14031.csv
#   32. diarios_14032.csv
#   33. diarios_14033.csv
#   34. diarios_14034.csv
#   35. diarios_14035.csv
#   36. diarios_14036.csv
#   37. diarios_14037.csv
#   38. diarios_14038.csv
#   39. diarios_14039.csv
#   40. diarios_14040.csv
#   41. diarios_14041.csv
#   42. diarios_14042.csv
#   43. diarios_14043.csv
#   44. diarios_14044.csv
#   45. diarios_14045.csv
#   46. diarios_14046.csv
#   47. diarios_14047.csv
#   48. diarios_14048.csv
#   49. diarios_14049.csv
#   50. diarios_14050.csv
#   51. diarios_14051.csv
#   52. diarios_14052.csv
#   53. diarios_14053.csv
#   54. diarios_14054.csv
#   55. diarios_14055.csv
#   56. diarios_14056.csv
#   57. diarios_14057.csv
#   58. diarios_14058.csv
#   59. diarios_14059.csv
#   60. diarios_14060.csv
#   61. diarios_14062.csv
#   62. diarios_14063.csv
#   63. diarios_14064.csv
#   64. diarios_14065.csv
#   65. diarios_14066.csv
#   66. diarios_14067.csv
#   67. diarios_14068.csv
#   68. diarios_14069.csv
#   69. diarios_14070.csv
#   70. diarios_14071.csv
#   71. diarios_14072.csv
#   72. diarios_14073.csv
#   73. diarios_14074.csv
#   74. diarios_14075.csv
#   75. diarios_14076.csv
#   76. diarios_14077.csv
#   77. diarios_14078.csv
#   78. diarios_14079.csv
#   79. diarios_14080.csv
#   80. diarios_14081.csv
#   81. diarios_14082.csv
#   82. diarios_14083.csv
#   83. diarios_14084.csv
#   84. diarios_14085.csv
#   85. diarios_14086.csv
#   86. diarios_14087.csv
#   87. diarios_14088.csv
#   88. diarios_14089.csv
#   89. diarios_14090.csv
#   90. diarios_14091.csv
#   91. diarios_14092.csv
#   92. diarios_14093.csv
#   93. diarios_14094.csv
#   94. diarios_14095.csv
#   95. diarios_14096.csv
#   96. diarios_14097.csv
#   97. diarios_14098.csv
#   98. diarios_14099.csv
#   99. diarios_14100.csv
#   100. diarios_14101.csv
#   101. diarios_14102.csv
#   102. diarios_14103.csv
#   103. diarios_14104.csv
#   104. diarios_14105.csv
#   105. diarios_14106.csv
#   106. diarios_14107.csv
#   107. diarios_14108.csv
#   108. diarios_14109.csv
#   109. diarios_14110.csv
#   110. diarios_14111.csv
#   111. diarios_14112.csv
#   112. diarios_14113.csv
#   113. diarios_14114.csv
#   114. diarios_14115.csv
#   115. diarios_14116.csv
#   116. diarios_14117.csv
#   117. diarios_14118.csv
#   118. diarios_14119.csv
#   119. diarios_14120.csv
#   120. diarios_14121.csv
#   121. diarios_14122.csv
#   122. diarios_14123.csv
#   123. diarios_14124.csv
#   124. diarios_14125.csv
#   125. diarios_14126.csv
#   126. diarios_14127.csv
#   127. diarios_14128.csv
#   128. diarios_14129.csv
#   129. diarios_14130.csv
#   130. diarios_14131.csv
#   131. diarios_14132.csv
#   132. diarios_14133.csv
#   133. diarios_14134.csv
#   134. diarios_14135.csv
#   135. diarios_14136.csv
#   136. diarios_14138.csv
#   137. diarios_14139.csv
#   138. diarios_14140.csv
#   139. diarios_14141.csv
#   140. diarios_14142.csv
#   141. diarios_14143.csv
#   142. diarios_14144.csv
#   143. diarios_14145.csv
#   144. diarios_14146.csv
#   145. diarios_14147.csv
#   146. diarios_14148.csv
#   147. diarios_14149.csv
#   148. diarios_14151.csv
#   149. diarios_14152.csv
#   150. diarios_14153.csv
#   151. diarios_14154.csv
#   152. diarios_14155.csv
#   153. diarios_14156.csv
#   154. diarios_14157.csv
#   155. diarios_14158.csv
#   156. diarios_14159.csv
#   157. diarios_14160.csv
#   158. diarios_14161.csv
#   159. diarios_14162.csv
#   160. diarios_14163.csv
#   161. diarios_14164.csv
#   162. diarios_14165.csv
#   163. diarios_14166.csv
#   164. diarios_14167.csv
#   165. diarios_14168.csv
#   166. diarios_14169.csv
#   167. diarios_14170.csv
#   168. diarios_14171.csv
#   169. diarios_14173.csv
#   170. diarios_14174.csv
#   171. diarios_14175.csv
#   172. diarios_14176.csv
#   173. diarios_14177.csv
#   174. diarios_14178.csv
#   175. diarios_14179.csv
#   176. diarios_14180.csv
#   177. diarios_14182.csv
#   178. diarios_14183.csv
#   179. diarios_14184.csv
#   180. diarios_14185.csv
#   181. diarios_14186.csv
#   182. diarios_14187.csv
#   183. diarios_14188.csv
#   184. diarios_14189.csv
#   185. diarios_14190.csv
#   186. diarios_14191.csv
#   187. diarios_14192.csv
#   188. diarios_14195.csv
#   189. diarios_14196.csv
#   190. diarios_14197.csv
#   191. diarios_14198.csv
#   192. diarios_14199.csv
#   193. diarios_14200.csv
#   194. diarios_14202.csv
#   195. diarios_14266.csv
#   196. diarios_14269.csv
#   197. diarios_14271.csv
#   198. diarios_14276.csv
#   199. diarios_14277.csv
#   200. diarios_14278.csv
#   201. diarios_14279.csv
#   202. diarios_14280.csv
#   203. diarios_14281.csv
#   204. diarios_14287.csv
#   205. diarios_14292.csv
#   206. diarios_14294.csv
#   207. diarios_14295.csv
#   208. diarios_14296.csv
#   209. diarios_14297.csv
#   210. diarios_14301.csv
#   211. diarios_14302.csv
#   212. diarios_14304.csv
#   213. diarios_14306.csv
#   214. diarios_14307.csv
#   215. diarios_14308.csv
#   216. diarios_14309.csv
#   217. diarios_14310.csv
#   218. diarios_14311.csv
#   219. diarios_14312.csv
#   220. diarios_14313.csv
#   221. diarios_14314.csv
#   222. diarios_14315.csv
#   223. diarios_14316.csv
#   224. diarios_14317.csv
#   225. diarios_14318.csv
#   226. diarios_14319.csv
#   227. diarios_14320.csv
#   228. diarios_14322.csv
#   229. diarios_14323.csv
#   230. diarios_14324.csv
#   231. diarios_14325.csv
#   232. diarios_14326.csv
#   233. diarios_14327.csv
#   234. diarios_14329.csv
#   235. diarios_14330.csv
#   236. diarios_14331.csv
#   237. diarios_14333.csv
#   238. diarios_14336.csv
#   239. diarios_14337.csv
#   240. diarios_14338.csv
#   241. diarios_14339.csv
#   242. diarios_14340.csv
#   243. diarios_14342.csv
#   244. diarios_14343.csv
#   245. diarios_14344.csv
#   246. diarios_14345.csv
#   247. diarios_14346.csv
#   248. diarios_14347.csv
#   249. diarios_14348.csv
#   250. diarios_14349.csv
#   251. diarios_14350.csv
#   252. diarios_14351.csv
#   253. diarios_14352.csv
#   254. diarios_14355.csv
#   255. diarios_14356.csv
#   256. diarios_14360.csv
#   257. diarios_14362.csv
#   258. diarios_14363.csv
#   259. diarios_14365.csv
#   260. diarios_14367.csv
#   261. diarios_14368.csv
#   262. diarios_14369.csv
#   263. diarios_14373.csv
#   264. diarios_14376.csv
#   265. diarios_14377.csv
#   266. diarios_14379.csv
#   267. diarios_14380.csv
#   268. diarios_14386.csv
#   269. diarios_14387.csv
#   270. diarios_14388.csv
#   271. diarios_14390.csv
#   272. diarios_14391.csv
#   273. diarios_14392.csv
#   274. diarios_14395.csv
#   275. diarios_14396.csv
#   276. diarios_14397.csv
#   277. reporte_estaciones.csv
#
# ¿Desea descargar todos los archivos? (s/n): s
# 📦 Descargando archivo comprimido...
# ✅ Descarga completada
