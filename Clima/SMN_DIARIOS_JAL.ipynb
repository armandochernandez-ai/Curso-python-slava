# %% [markdown]
# <a href="https://colab.research.google.com/github/armandochernandez-ai/Curso-python-slava/blob/main/Clima/SMN_DIARIOS_JAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
import time
import re
import os
from datetime import datetime
import pandas as pd

# Configuración para Google Colab
try:
    from google.colab import drive
    IN_COLAB = True
except:
    IN_COLAB = False

# Configuración
BASE_URL = "https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal"
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'es-MX,es;q=0.9',
}

# Variables disponibles en los datos diarios con nuevos nombres
VARIABLES_DIARIAS = ['p', 'evap', 'tmax', 'tmin']
VARIABLES_ORIGINALES = ['PRECIP', 'EVAP', 'TMAX', 'TMIN']
VARIABLE_MAPPING = dict(zip(VARIABLES_ORIGINALES, VARIABLES_DIARIAS))

# Valores que deben ser reemplazados por NA (incluyendo NULO)
VALORES_NULOS = ['', 'N/D', '-', '--', '---', '////', '****', '*****', 'NULL', 'null', 'N/A', 'n/a', 'NULO']

def configurar_entorno_colab():
    """Configura el entorno para Google Colab"""
    if IN_COLAB:
        print("Montando Google Drive...")
        drive.mount('/content/drive')

        # Crear directorio base si no existe
        directorio_base = "/content/drive/MyDrive/Clima_Jalisco"
        directorio_datos = "/content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS"

        os.makedirs(directorio_base, exist_ok=True)
        os.makedirs(directorio_datos, exist_ok=True)

        print(f"Directorio de trabajo configurado en: {directorio_datos}")
        return directorio_datos
    else:
        # Si no está en Colab, usar directorio local
        directorio_local = "Clima_Jalisco/DATOS_DIARIOS"
        os.makedirs(directorio_local, exist_ok=True)
        return directorio_local

def descargar_datos_estacion(clave):
    """Descarga los datos diarios de una estación específica"""
    url = f"{BASE_URL}/dia{clave}.txt"
    try:
        print(f"  Descargando de: {url}")
        response = requests.get(url, headers=HEADERS, timeout=30)
        response.raise_for_status()

        # Verificar si el contenido es válido
        if len(response.text.strip()) < 50:
            print(f"  Contenido insuficiente para estación {clave}")
            return None

        return response.text
    except requests.exceptions.HTTPError as e:
        if e.response.status_code == 404:
            print(f"  Estación {clave} no encontrada (404)")
        else:
            print(f"  Error HTTP {e.response.status_code} para estación {clave}")
        return None
    except Exception as e:
        print(f"  Error descargando datos para estación {clave}: {str(e)}")
        return None

def extraer_info_basica(contenido):
    """Extrae la información básica de la estación"""
    datos = {
        'Codigo': '',
        'site': '',
        'estado': 'Jalisco',
        'municipio': '',
        'situacion': '',
        'lat': '',
        'lon': '',
        'alt': ''
    }

    lineas = contenido.split('\n')
    for linea in lineas:
        linea = linea.strip()
        if 'ESTACIÓN  :' in linea:
            datos['Codigo'] = linea.split(':')[1].strip()
        elif 'NOMBRE    :' in linea:
            datos['site'] = linea.split(':')[1].strip()
        elif 'MUNICIPIO :' in linea:
            datos['municipio'] = linea.split(':')[1].strip()
        elif 'SITUACIÓN :' in linea:
            datos['situacion'] = linea.split(':')[1].strip()
        elif 'LATITUD   :' in linea:
            datos['lat'] = linea.split(':')[1].replace('°', '').strip()
        elif 'LONGITUD  :' in linea:
            datos['lon'] = linea.split(':')[1].replace('°', '').strip()
        elif 'ALTITUD   :' in linea:
            datos['alt'] = linea.split(':')[1].replace('msnm', '').strip()

    return datos

def limpiar_valor(valor):
    """Limpia y valida los valores, reemplazando nulos por NA"""
    if valor is None:
        return 'NA'

    valor_str = str(valor).strip()

    # Si está vacío o en la lista de valores nulos (incluyendo NULO)
    if not valor_str or valor_str in VALORES_NULOS:
        return 'NA'

    # Si son solo asteriscos o caracteres no válidos
    if re.match(r'^[*\-/\s]+$', valor_str):
        return 'NA'

    return valor_str

def parsear_datos_diarios(contenido):
    """Extrae los datos diarios del contenido, manejando valores NULO"""
    lineas = contenido.split('\n')
    datos_diarios = []

    # Bandera para indicar cuando empezar a leer datos
    empezar_datos = False
    patron_fecha_guion = re.compile(r'^\d{4}-\d{1,2}-\d{1,2}')  # Formato YYYY-MM-DD
    patron_fecha_slash = re.compile(r'^\d{1,2}/\d{1,2}/\d{4}')  # Formato DD/MM/YYYY

    # Buscar la línea de encabezados
    for i, linea in enumerate(lineas):
        linea = linea.strip()

        # Buscar el inicio de la tabla de datos
        if 'FECHA' in linea and any(var in linea for var in VARIABLES_ORIGINALES):
            empezar_datos = True
            # Saltar la siguiente línea (unidades) si existe
            continue

        # Si estamos en la sección de datos, procesar línea
        if empezar_datos and linea:
            # Verificar si es una línea de datos (comienza con fecha en formato YYYY-MM-DD o DD/MM/YYYY)
            if patron_fecha_guion.match(linea) or patron_fecha_slash.match(linea):
                # Dividir por tabs (parece que están separados por tabs en el ejemplo)
                partes = linea.split('\t')

                # Si no hay tabs, intentar con espacios múltiples
                if len(partes) < 2:
                    partes = re.split(r'\s{2,}', linea)

                # Si aún no funciona, usar split simple
                if len(partes) < 2:
                    partes = linea.split()

                # Filtrar partes vacías
                partes = [p.strip() for p in partes if p.strip()]

                # Debe tener al menos la fecha
                if len(partes) >= 1:
                    fecha = partes[0]

                    # Procesar valores para cada variable
                    valores = {}

                    # Asignar valores según posición esperada
                    # Orden esperado: FECHA, PRECIP, EVAP, TMAX, TMIN
                    if len(partes) > 1:
                        valores['p'] = limpiar_valor(partes[1])
                    else:
                        valores['p'] = 'NA'

                    if len(partes) > 2:
                        valores['evap'] = limpiar_valor(partes[2])
                    else:
                        valores['evap'] = 'NA'

                    if len(partes) > 3:
                        valores['tmax'] = limpiar_valor(partes[3])
                    else:
                        valores['tmax'] = 'NA'

                    if len(partes) > 4:
                        valores['tmin'] = limpiar_valor(partes[4])
                    else:
                        valores['tmin'] = 'NA'

                    # Crear registro
                    registro = {
                        'date': fecha,
                        **valores
                    }
                    datos_diarios.append(registro)

            # Si encontramos líneas que indican el final de los datos
            elif any(palabra in linea.upper() for palabra in ['PROMEDIO', 'TOTAL', 'MEDIA', 'FIN DE DATOS']):
                break

    # Si no encontramos datos con el método anterior, intentar método más flexible
    if not datos_diarios:
        datos_diarios = parsear_datos_flexible(contenido)

    print(f"    Se extrajeron {len(datos_diarios)} registros diarios")

    # Depuración: mostrar primeros 3 registros si hay datos
    if datos_diarios:
        print(f"    Primeros registros: {datos_diarios[:3]}")

    return datos_diarios

def parsear_datos_flexible(contenido):
    """Método más flexible para extraer datos cuando el método principal falla"""
    lineas = contenido.split('\n')
    datos_diarios = []

    # Patrones de fecha
    patron_fecha_guion = re.compile(r'^\d{4}-\d{1,2}-\d{1,2}')  # YYYY-MM-DD
    patron_fecha_slash = re.compile(r'^\d{1,2}/\d{1,2}/\d{4}')   # DD/MM/YYYY

    # Buscar cualquier línea que empiece con fecha
    for linea in lineas:
        linea = linea.strip()

        # Verificar si es una línea de datos (comienza con fecha)
        if patron_fecha_guion.match(linea) or patron_fecha_slash.match(linea):
            # Dividir por cualquier tipo de espacio (tabs, espacios múltiples)
            partes = re.split(r'\t|\s{2,}', linea)

            # Si no funciona, usar split simple
            if len(partes) < 2:
                partes = linea.split()

            # Filtrar partes vacías
            partes = [p.strip() for p in partes if p.strip()]

            if len(partes) >= 1:
                fecha = partes[0]
                valores = {}

                # Mapear las variables por posición
                for i, var in enumerate(VARIABLES_DIARIAS):
                    if i + 1 < len(partes):
                        valores[var] = limpiar_valor(partes[i + 1])
                    else:
                        valores[var] = 'NA'

                registro = {'date': fecha, **valores}
                datos_diarios.append(registro)

    return datos_diarios

def guardar_datos_estacion(directorio_salida, estacion_info, datos_diarios):
    """Guarda los datos diarios de una estación en archivo CSV"""
    if not datos_diarios:
        print(f"  No hay datos diarios para guardar de la estación {estacion_info['Codigo']}")
        return False

    # Crear nombre de archivo
    archivo_csv = os.path.join(directorio_salida, f"diarios_{estacion_info['Codigo']}.csv")

    # Campos del CSV con nuevos nombres
    campos = ['Codigo', 'site', 'municipio', 'lat', 'lon', 'alt', 'date'] + VARIABLES_DIARIAS

    try:
        # Escribir datos
        with open(archivo_csv, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=campos)
            writer.writeheader()

            for registro in datos_diarios:
                fila = {
                    'Codigo': estacion_info['Codigo'],
                    'site': estacion_info['site'],
                    'municipio': estacion_info['municipio'],
                    'lat': estacion_info['lat'],
                    'lon': estacion_info['lon'],
                    'alt': estacion_info['alt'],
                    'date': registro['date'],
                    'p': registro.get('p', 'NA'),
                    'evap': registro.get('evap', 'NA'),
                    'tmax': registro.get('tmax', 'NA'),
                    'tmin': registro.get('tmin', 'NA')
                }
                writer.writerow(fila)

        print(f"  Datos guardados en: {archivo_csv}")
        return True
    except Exception as e:
        print(f"  Error guardando archivo para estación {estacion_info['Codigo']}: {str(e)}")
        return False

def guardar_datos_unidos(directorio_salida, estacion_info, datos_diarios):
    """Guarda todos los datos en un archivo CSV unificado"""
    if not datos_diarios:
        return

    archivo_unido = os.path.join(directorio_salida, "datos_diarios_unidos.csv")

    # Campos del CSV con nuevos nombres
    campos = ['Codigo', 'site', 'municipio', 'lat', 'lon', 'alt', 'date'] + VARIABLES_DIARIAS

    try:
        # Verificar si el archivo existe para no sobrescribir el encabezado
        modo = 'a' if os.path.exists(archivo_unido) else 'w'

        with open(archivo_unido, modo, newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=campos)

            if modo == 'w':
                writer.writeheader()
                print(f"  Creando archivo unificado: {archivo_unido}")

            for registro in datos_diarios:
                fila = {
                    'Codigo': estacion_info['Codigo'],
                    'site': estacion_info['site'],
                    'municipio': estacion_info['municipio'],
                    'lat': estacion_info['lat'],
                    'lon': estacion_info['lon'],
                    'alt': estacion_info['alt'],
                    'date': registro['date'],
                    'p': registro.get('p', 'NA'),
                    'evap': registro.get('evap', 'NA'),
                    'tmax': registro.get('tmax', 'NA'),
                    'tmin': registro.get('tmin', 'NA')
                }
                writer.writerow(fila)
    except Exception as e:
        print(f"  Error actualizando archivo unificado: {str(e)}")

def procesar_estacion(clave, directorio_salida):
    """Procesa una estación individual"""
    print(f"Procesando estación: {clave}")

    contenido = descargar_datos_estacion(clave)

    if not contenido:
        print(f"  No se pudieron obtener datos para la estación {clave}")
        return

    # Extraer información básica de la estación
    estacion_info = extraer_info_basica(contenido)

    # Si no se pudo extraer la clave, usar la clave proporcionada
    if not estacion_info['Codigo']:
        estacion_info['Codigo'] = clave

    print(f"  Estación: {estacion_info['site']} ({estacion_info['municipio']})")

    # Extraer datos diarios
    datos_diarios = parsear_datos_diarios(contenido)

    if datos_diarios:
        # Guardar en archivo individual de la estación
        guardar_datos_estacion(directorio_salida, estacion_info, datos_diarios)

        # Guardar en archivo unificado
        guardar_datos_unidos(directorio_salida, estacion_info, datos_diarios)
    else:
        print(f"  No se encontraron datos diarios para esta estación")
        # Depuración: mostrar algunas líneas del contenido para diagnóstico
        lineas = contenido.split('\n')
        print(f"  Primeras 15 líneas del contenido para diagnóstico:")
        for i, linea in enumerate(lineas[:15]):
            print(f"    Línea {i}: {repr(linea)}")

    time.sleep(1)  # Espera entre descargas para no saturar el servidor

def leer_archivo_estaciones(nombre_archivo):
    """Lee el archivo de estaciones con manejo de codificaciones"""
    try:
        with open(nombre_archivo, 'r', encoding='utf-8') as f:
            lineas = [linea.strip() for linea in f.readlines() if linea.strip()]
            print(f"Se leyeron {len(lineas)} estaciones del archivo")
            return lineas
    except UnicodeDecodeError:
        try:
            with open(nombre_entrada, 'r', encoding='latin-1') as f:
                lineas = [linea.strip() for linea in f.readlines() if linea.strip()]
                print(f"Se leyeron {len(lineas)} estaciones del archivo (codificación latin-1)")
                return lineas
        except Exception as e:
            print(f"Error leyendo archivo de estaciones: {str(e)}")
            return []
    except Exception as e:
        print(f"Error leyendo archivo de estaciones: {str(e)}")
        return []

def generar_reporte_estaciones(directorio_salida):
    """Genera un reporte de las estaciones procesadas"""
    archivos = [f for f in os.listdir(directorio_salida) if f.startswith('diarios_') and f.endswith('.csv')]

    reporte = []
    for archivo in archivos:
        clave = archivo.replace('diarios_', '').replace('.csv', '')
        ruta_archivo = os.path.join(directorio_salida, archivo)

        try:
            with open(ruta_archivo, 'r', encoding='utf-8') as f:
                lineas = f.readlines()
                if len(lineas) > 1:  # Tiene encabezado y al menos un dato
                    num_registros = len(lineas) - 1
                    reporte.append({
                        'Codigo': clave,
                        'archivo': archivo,
                        'registros': num_registros
                    })
        except:
            continue

    # Guardar reporte
    if reporte:
        archivo_reporte = os.path.join(directorio_salida, "reporte_estaciones.csv")
        with open(archivo_reporte, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['Codigo', 'archivo', 'registros'])
            writer.writeheader()
            writer.writerows(reporte)

        print(f"\nReporte generado: {archivo_reporte}")
        print(f"Total de estaciones con datos: {len(reporte)}")

        # Mostrar resumen
        for est in reporte:
            print(f"  {est['Codigo']}: {est['registros']} registros")

def main():
    print("Sistema de Extracción de Datos Meteorológicos Diarios de Jalisco")
    print("Variables: date, p, evap, tmax, tmin")
    print("Valores nulos (incluyendo 'NULO') se reemplazan por: NA")

    # Configurar entorno (Colab o local)
    directorio_salida = configurar_entorno_colab()

    # Opción 1: Procesar desde archivo de entrada
    archivo_entrada = "estaciones.txt"

    # Si estamos en Colab, buscar el archivo en Drive también
    if IN_COLAB and not os.path.exists(archivo_entrada):
        # Intentar encontrar el archivo en diferentes ubicaciones de Drive
        posibles_rutas = [
            "/content/drive/MyDrive/estaciones.txt",
            "/content/drive/MyDrive/Clima_Jalisco/estaciones.txt",
            "/content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/estaciones.txt",
            "/content/estaciones.txt"
        ]

        for ruta in posibles_rutas:
            if os.path.exists(ruta):
                archivo_entrada = ruta
                print(f"Archivo de estaciones encontrado en: {ruta}")
                break

    estaciones = []

    if os.path.exists(archivo_entrada):
        estaciones = leer_archivo_estaciones(archivo_entrada)
    else:
        print(f"Archivo {archivo_entrada} no encontrado")

    # Si no hay estaciones del archivo, usar lista por defecto
    if not estaciones:
        print("Usando lista de estaciones por defecto")
        estaciones = ['14001', '14002', '14003', '14004', '14005',
                     '14006', '14007', '14008', '14009', '14010',
                     '14011', '14012', '14013', '14014', '14015']

    if estaciones:
        total = len(estaciones)
        print(f"\nProcesando {total} estaciones...")

        exitosas = 0
        for i, clave in enumerate(estaciones, 1):
            print(f"\n[{i}/{total}] ", end="")
            procesar_estacion(clave, directorio_salida)
            if os.path.exists(os.path.join(directorio_salida, f"diarios_{clave}.csv")):
                exitosas += 1

        print(f"\n¡Proceso completado!")
        print(f"Estaciones con datos extraídos: {exitosas}/{total}")
        print(f"Datos guardados en: {directorio_salida}")

        # Generar reporte
        generar_reporte_estaciones(directorio_salida)
    else:
        print("No se encontraron estaciones para procesar")

if __name__ == "__main__":
    main()
# Out:
# Sistema de Extracción de Datos Meteorológicos Diarios de Jalisco
# Variables: date, p, evap, tmax, tmin
# Valores nulos (incluyendo 'NULO') se reemplazan por: NA
# Montando Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Directorio de trabajo configurado en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS
# Archivo de estaciones encontrado en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/estaciones.txt
# Se leyeron 275 estaciones del archivo
#
# Procesando 275 estaciones...
#
# [1/275] Procesando estación: 14001
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14001.txt
#   Estación: ACATIC (SMN) (ACATIC)
#     Se extrajeron 4429 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14001.csv
#   Creando archivo unificado: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/datos_diarios_unidos.csv
#
# [2/275] Procesando estación: 14002
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14002.txt
#   Estación: ACATLAN DE JUAREZ (ACATLÁN DE JUÁREZ)
#     Se extrajeron 22289 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': '27', 'tmin': '6'}, {'date': '1961-01-02', 'p': '0', 'evap': 'NA', 'tmax': '28.5', 'tmin': '7'}, {'date': '1961-01-03', 'p': '0', 'evap': 'NA', 'tmax': '27.5', 'tmin': '7.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14002.csv
#
# [3/275] Procesando estación: 14004
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14004.txt
#   Estación: AGOSTADERO (SAN JUAN DE LOS LAGOS)
#     Se extrajeron 9876 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': '4.5', 'tmax': '27', 'tmin': '6.5'}, {'date': '1961-01-02', 'p': '0', 'evap': '4.6', 'tmax': '28', 'tmin': '2'}, {'date': '1961-01-03', 'p': '0', 'evap': '2.4', 'tmax': '30', 'tmin': '1.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14004.csv
#
# [4/275] Procesando estación: 14005
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14005.txt
#   Estación: AHUIJULLO (TECALITLÁN)
#     Se extrajeron 8994 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14005.csv
#
# [5/275] Procesando estación: 14006
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14006.txt
#   Estación: AJOJUCAR (TEOCALTICHE)
#     Se extrajeron 30156 registros diarios
#     Primeros registros: [{'date': '1940-07-09', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1940-07-10', 'p': '5.5', 'evap': 'NA', 'tmax': '35', 'tmin': '19'}, {'date': '1940-07-11', 'p': '5', 'evap': 'NA', 'tmax': '25', 'tmin': '16'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14006.csv
#
# [6/275] Procesando estación: 14007
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14007.txt
#   Estación: ACIHUATL (VILLA PURIFICACIÓN)
#     Se extrajeron 5026 registros diarios
#     Primeros registros: [{'date': '1969-02-01', 'p': '0', 'evap': '2.8', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-02-02', 'p': '0', 'evap': '3.8', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-02-03', 'p': '0', 'evap': '3.6', 'tmax': '32.9', 'tmin': '10.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14007.csv
#
# [7/275] Procesando estación: 14008
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14008.txt
#   Estación: AMACUECA (AMACUECA)
#     Se extrajeron 10526 registros diarios
#     Primeros registros: [{'date': '1962-04-11', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1962-04-12', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1962-04-13', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14008.csv
#
# [8/275] Procesando estación: 14009
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14009.txt
#   Estación: AMECA (AMECA)
#     Se extrajeron 29640 registros diarios
#     Primeros registros: [{'date': '1923-02-01', 'p': '0', 'evap': 'NA', 'tmax': '22.2', 'tmin': '9'}, {'date': '1923-02-02', 'p': '0', 'evap': 'NA', 'tmax': '23', 'tmin': '10'}, {'date': '1923-02-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14009.csv
#
# [9/275] Procesando estación: 14010
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14010.txt
#   Estación: ANTONIO ESCOBEDO (SMN) (SAN JUANITO DE ESCOBEDO)
#     Se extrajeron 16495 registros diarios
#     Primeros registros: [{'date': '1939-04-05', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1939-04-06', 'p': '0', 'evap': '5', 'tmax': '33.4', 'tmin': '10.4'}, {'date': '1939-04-07', 'p': '0', 'evap': '4.1', 'tmax': '33.4', 'tmin': '6.2'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14010.csv
#
# [10/275] Procesando estación: 14011
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14011.txt
#   Estación: APAZULCO (LA HUERTA)
#     Se extrajeron 22304 registros diarios
#     Primeros registros: [{'date': '1961-07-01', 'p': '0', 'evap': 'NA', 'tmax': '31.5', 'tmin': '21'}, {'date': '1961-07-02', 'p': '0', 'evap': 'NA', 'tmax': '36', 'tmin': '15.5'}, {'date': '1961-07-03', 'p': '0', 'evap': 'NA', 'tmax': '36.5', 'tmin': '22.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14011.csv
#
# [11/275] Procesando estación: 14012
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14012.txt
#   Estación: EL ARENAL (SMN) (EL ARENAL)
#     Se extrajeron 6322 registros diarios
#     Primeros registros: [{'date': '1959-10-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1959-10-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1959-10-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14012.csv
#
# [12/275] Procesando estación: 14013
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14013.txt
#   Estación: ATEMAJAC DE BRIZUELA (ATEMAJAC DE BRIZUELA)
#     Se extrajeron 21232 registros diarios
#     Primeros registros: [{'date': '1945-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1945-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1945-01-03', 'p': '9', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14013.csv
#
# [13/275] Procesando estación: 14014
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14014.txt
#   Estación: ATENGO (SMN) (ATENGO)
#     Se extrajeron 14571 registros diarios
#     Primeros registros: [{'date': '1945-07-01', 'p': '5.5', 'evap': 'NA', 'tmax': '25.3', 'tmin': '25'}, {'date': '1945-07-02', 'p': '0', 'evap': 'NA', 'tmax': '24.4', 'tmin': '23.7'}, {'date': '1945-07-03', 'p': '5.5', 'evap': 'NA', 'tmax': '24', 'tmin': '22.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14014.csv
#
# [14/275] Procesando estación: 14015
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14015.txt
#   Estación: ATENGUILLO (ATENGUILLO)
#     Se extrajeron 16481 registros diarios
#     Primeros registros: [{'date': '1950-10-01', 'p': '0', 'evap': '3.68', 'tmax': '26.8', 'tmin': '16.1'}, {'date': '1950-10-02', 'p': '4.2', 'evap': '2.64', 'tmax': '28.8', 'tmin': '15.2'}, {'date': '1950-10-03', 'p': '5.2', 'evap': '4.86', 'tmax': '28.6', 'tmin': '12.2'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14015.csv
#
# [15/275] Procesando estación: 14016
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14016.txt
#   Estación: ATEQUIZA (IXTLAHUACÁN DE LOS MEMBRILLOS)
#     Se extrajeron 26401 registros diarios
#     Primeros registros: [{'date': '1951-01-01', 'p': '0', 'evap': '3', 'tmax': '24', 'tmin': '4'}, {'date': '1951-01-02', 'p': '0', 'evap': '2.9', 'tmax': '24', 'tmin': '5'}, {'date': '1951-01-03', 'p': '0', 'evap': '2.8', 'tmax': '24', 'tmin': '2'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14016.csv
#
# [16/275] Procesando estación: 14017
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14017.txt
#   Estación: ATOTONILCO EL ALTO (ATOTONILCO EL ALTO)
#     Se extrajeron 26760 registros diarios
#     Primeros registros: [{'date': '1942-10-01', 'p': '3.5', 'evap': 'NA', 'tmax': '29', 'tmin': '14'}, {'date': '1942-10-02', 'p': '0', 'evap': 'NA', 'tmax': '25', 'tmin': '17'}, {'date': '1942-10-03', 'p': '0', 'evap': 'NA', 'tmax': '23', 'tmin': '13'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14017.csv
#
# [17/275] Procesando estación: 14018
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14018.txt
#   Estación: ATOYAC (ATOYAC)
#     Se extrajeron 28386 registros diarios
#     Primeros registros: [{'date': '1943-08-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-08-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-08-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14018.csv
#
# [18/275] Procesando estación: 14019
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14019.txt
#   Estación: AUTLAN (AUTLÁN DE NAVARRO)
#     Se extrajeron 17516 registros diarios
#     Primeros registros: [{'date': '1945-10-01', 'p': '5', 'evap': 'NA', 'tmax': '25', 'tmin': '22'}, {'date': '1945-10-02', 'p': '0', 'evap': 'NA', 'tmax': '25.5', 'tmin': '22'}, {'date': '1945-10-03', 'p': '5', 'evap': 'NA', 'tmax': '26', 'tmin': '21'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14019.csv
#
# [19/275] Procesando estación: 14020
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14020.txt
#   Estación: AYO EL CHICO (AYOTLÁN)
#     Se extrajeron 14148 registros diarios
#     Primeros registros: [{'date': '1948-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-04-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-04-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14020.csv
#
# [20/275] Procesando estación: 14021
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14021.txt
#   Estación: AYOTITLAN (CUAUTITLÁN DE GARCÍA BARRAGÁN)
#     Se extrajeron 9473 registros diarios
#     Primeros registros: [{'date': '1961-07-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-07-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-07-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14021.csv
#
# [21/275] Procesando estación: 14022
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14022.txt
#   Estación: CLAVELLINAS (TUXPAN)
#     Se extrajeron 1152 registros diarios
#     Primeros registros: [{'date': '1993-01-01', 'p': '0', 'evap': '3.79', 'tmax': '29', 'tmin': '15'}, {'date': '1993-01-02', 'p': '0', 'evap': '4.91', 'tmax': '31', 'tmin': '12'}, {'date': '1993-01-03', 'p': '0', 'evap': '4.69', 'tmax': '32', 'tmin': '11'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14022.csv
#
# [22/275] Procesando estación: 14023
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14023.txt
#   Estación: BOLAÑOS (BOLAÑOS)
#     Se extrajeron 27741 registros diarios
#     Primeros registros: [{'date': '1947-02-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1947-02-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1947-02-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14023.csv
#
# [23/275] Procesando estación: 14024
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14024.txt
#   Estación: CAJON DE PEÑA (TOMATLÁN)
#     Se extrajeron 23399 registros diarios
#     Primeros registros: [{'date': '1954-08-01', 'p': '1.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1954-08-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1954-08-03', 'p': '8.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14024.csv
#
# [24/275] Procesando estación: 14025
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14025.txt
#   Estación: CALERA (TEOCALTICHE)
#     Se extrajeron 18362 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': '5.6', 'tmax': '27', 'tmin': '5'}, {'date': '1961-01-02', 'p': '0', 'evap': '1.9', 'tmax': '25', 'tmin': '8'}, {'date': '1961-01-03', 'p': '0', 'evap': '3', 'tmax': '26', 'tmin': '2'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14025.csv
#
# [25/275] Procesando estación: 14026
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14026.txt
#   Estación: CASA LLANTA (COLOTLÁN)
#     Se extrajeron 23605 registros diarios
#     Primeros registros: [{'date': '1957-07-01', 'p': '0', 'evap': '11.76', 'tmax': '33.5', 'tmin': '23'}, {'date': '1957-07-02', 'p': '0', 'evap': '9.38', 'tmax': '33.5', 'tmin': '19'}, {'date': '1957-07-03', 'p': '0', 'evap': '11.21', 'tmax': '34', 'tmin': '17'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14026.csv
#
# [26/275] Procesando estación: 14027
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14027.txt
#   Estación: CASIMIRO CASTILLO (CASIMIRO CASTILLO)
#     Se extrajeron 15680 registros diarios
#     Primeros registros: [{'date': '1953-10-08', 'p': '14', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1953-10-09', 'p': '27.2', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1953-10-10', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14027.csv
#
# [27/275] Procesando estación: 14028
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14028.txt
#   Estación: CIHUATLAN (DGE) (CIHUATLÁN)
#     Se extrajeron 26569 registros diarios
#     Primeros registros: [{'date': '1946-12-01', 'p': '0', 'evap': 'NA', 'tmax': '31.5', 'tmin': '20'}, {'date': '1946-12-02', 'p': '0', 'evap': 'NA', 'tmax': '32.5', 'tmin': '20'}, {'date': '1946-12-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14028.csv
#
# [28/275] Procesando estación: 14029
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14029.txt
#   Estación: CONCEPCION DE BUENOS AIRES (CONCEPCIÓN DE BUENOS AIRES)
#     Se extrajeron 18507 registros diarios
#     Primeros registros: [{'date': '1970-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1970-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1970-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14029.csv
#
# [29/275] Procesando estación: 14030
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14030.txt
#   Estación: CIUDAD GUZMAN (OBS) (ZAPOTLÁN EL GRANDE)
#     Se extrajeron 32678 registros diarios
#     Primeros registros: [{'date': '1897-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1897-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1897-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14030.csv
#
# [30/275] Procesando estación: 14031
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14031.txt
#   Estación: CIUDAD VENUSTIANO CARRANZA (SAN GABRIEL)
#     Se extrajeron 15333 registros diarios
#     Primeros registros: [{'date': '1946-06-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-06-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-06-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14031.csv
#
# [31/275] Procesando estación: 14032
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14032.txt
#   Estación: COLOTLAN (OBS) (COLOTLÁN)
#     Se extrajeron 15038 registros diarios
#     Primeros registros: [{'date': '1966-08-01', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1966-08-02', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1966-08-03', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14032.csv
#
# [32/275] Procesando estación: 14033
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14033.txt
#   Estación: COMANJA DE CORONA (LAGOS DE MORENO)
#     Se extrajeron 17755 registros diarios
#     Primeros registros: [{'date': '1963-02-14', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '2'}, {'date': '1963-02-15', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '2'}, {'date': '1963-02-16', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '4'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14033.csv
#
# [33/275] Procesando estación: 14034
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14034.txt
#   Estación: CONTLA (TAMAZULA DE GORDIANO)
#     Se extrajeron 19145 registros diarios
#     Primeros registros: [{'date': '1970-12-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1970-12-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1970-12-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14034.csv
#
# [34/275] Procesando estación: 14035
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14035.txt
#   Estación: CORRINCHIS II (MASCOTA)
#     Se extrajeron 22026 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': '3', 'tmax': '25', 'tmin': '6.5'}, {'date': '1961-01-02', 'p': '0', 'evap': '3', 'tmax': '25.5', 'tmin': '4'}, {'date': '1961-01-03', 'p': '0', 'evap': '3.2', 'tmax': '25.5', 'tmin': '3'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14035.csv
#
# [35/275] Procesando estación: 14036
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14036.txt
#   Estación: CUAUTITLAN (CUAUTITLÁN DE GARCÍA BARRAGÁN)
#     Se extrajeron 23908 registros diarios
#     Primeros registros: [{'date': '1958-06-07', 'p': '40.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1958-06-08', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1958-06-09', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14036.csv
#
# [36/275] Procesando estación: 14037
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14037.txt
#   Estación: PRESA ACHIMEC (HUEJÚCAR)
#     Se extrajeron 14478 registros diarios
#     Primeros registros: [{'date': '1969-01-01', 'p': '0.8', 'evap': 'NA', 'tmax': '23', 'tmin': '9'}, {'date': '1969-01-02', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '7'}, {'date': '1969-01-03', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '4'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14037.csv
#
# [37/275] Procesando estación: 14038
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14038.txt
#   Estación: CUIXTLA (SAN CRISTÓBAL DE LA BARRANCA)
#     Se extrajeron 25602 registros diarios
#     Primeros registros: [{'date': '1954-06-12', 'p': '0', 'evap': '8.47', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1954-06-13', 'p': '0', 'evap': '8.31', 'tmax': '36', 'tmin': '19.5'}, {'date': '1954-06-14', 'p': '0', 'evap': '8.6', 'tmax': '36.5', 'tmin': '22.3'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14038.csv
#
# [38/275] Procesando estación: 14039
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14039.txt
#   Estación: CUQUIO (CUQUÍO)
#     Se extrajeron 28196 registros diarios
#     Primeros registros: [{'date': '1943-06-01', 'p': '0.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-06-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-06-03', 'p': '1', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14039.csv
#
# [39/275] Procesando estación: 14040
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14040.txt
#   Estación: CHAPALA (CHAPALA)
#     Se extrajeron 32709 registros diarios
#     Primeros registros: [{'date': '1934-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1934-04-02', 'p': '0', 'evap': '5.9', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1934-04-03', 'p': '0', 'evap': '6.2', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14040.csv
#
# [40/275] Procesando estación: 14041
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14041.txt
#   Estación: CHIQUILISTLAN (CHIQUILISTLÁN)
#     Se extrajeron 7027 registros diarios
#     Primeros registros: [{'date': '1964-12-21', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1964-12-22', 'p': '0', 'evap': 'NA', 'tmax': '21.5', 'tmin': '12'}, {'date': '1964-12-23', 'p': '0', 'evap': '1.6', 'tmax': '26', 'tmin': '12.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14041.csv
#
# [41/275] Procesando estación: 14042
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14042.txt
#   Estación: CUITZMALA (LA HUERTA)
#     Se extrajeron 12080 registros diarios
#     Primeros registros: [{'date': '1955-06-06', 'p': '8.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-06-07', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-06-08', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14042.csv
#
# [42/275] Procesando estación: 14043
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14043.txt
#   Estación: EJUTLA (EJUTLA)
#     Se extrajeron 22192 registros diarios
#     Primeros registros: [{'date': '1940-07-14', 'p': '1.8', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1940-07-15', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1940-07-16', 'p': '3.7', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14043.csv
#
# [43/275] Procesando estación: 14044
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14044.txt
#   Estación: EL BRAMADOR (TALPA DE ALLENDE)
#     Se extrajeron 22013 registros diarios
#     Primeros registros: [{'date': '1959-08-01', 'p': '16.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1959-08-02', 'p': '25', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1959-08-03', 'p': '0.8', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14044.csv
#
# [44/275] Procesando estación: 14045
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14045.txt
#   Estación: CABRITO (ARANDAS)
#     Se extrajeron 3730 registros diarios
#     Primeros registros: [{'date': '1969-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14045.csv
#
# [45/275] Procesando estación: 14046
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14046.txt
#   Estación: EL CHANTE (AUTLÁN DE NAVARRO)
#     Se extrajeron 17244 registros diarios
#     Primeros registros: [{'date': '1969-11-07', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-11-08', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1969-11-09', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14046.csv
#
# [46/275] Procesando estación: 14047
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14047.txt
#   Estación: EL FUERTE (OCOTLÁN)
#     Se extrajeron 22079 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': '4.4', 'tmax': '25', 'tmin': '8'}, {'date': '1961-01-02', 'p': '0', 'evap': '4', 'tmax': '25', 'tmin': '8'}, {'date': '1961-01-03', 'p': '0', 'evap': '2.5', 'tmax': '25', 'tmin': '7'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14047.csv
#
# [47/275] Procesando estación: 14048
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14048.txt
#   Estación: EL CHIFLON (CIHUATLÁN)
#     Se extrajeron 23476 registros diarios
#     Primeros registros: [{'date': '1954-07-01', 'p': '10.5', 'evap': '3.84', 'tmax': '34', 'tmin': '23'}, {'date': '1954-07-02', 'p': '0', 'evap': '4.97', 'tmax': '34', 'tmin': '22'}, {'date': '1954-07-03', 'p': '37.5', 'evap': '3.67', 'tmax': '31.5', 'tmin': '22'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14048.csv
#
# [48/275] Procesando estación: 14049
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14049.txt
#   Estación: GARGANTILLO (TOMATLÁN)
#     Se extrajeron 9465 registros diarios
#     Primeros registros: [{'date': '1955-08-01', 'p': '26.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-08-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-08-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14049.csv
#
# [49/275] Procesando estación: 14050
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14050.txt
#   Estación: EL GRULLO (EL GRULLO)
#     Se extrajeron 16966 registros diarios
#     Primeros registros: [{'date': '1939-01-01', 'p': '0', 'evap': 'NA', 'tmax': '31', 'tmin': '10.5'}, {'date': '1939-01-02', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '10.5'}, {'date': '1939-01-03', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '8.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14050.csv
#
# [50/275] Procesando estación: 14051
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14051.txt
#   Estación: EL LIMON (EL LIMÓN)
#     Se extrajeron 10677 registros diarios
#     Primeros registros: [{'date': '1944-12-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1944-12-02', 'p': '0', 'evap': 'NA', 'tmax': '22.3', 'tmin': '13.2'}, {'date': '1944-12-03', 'p': '0', 'evap': 'NA', 'tmax': '22', 'tmin': '15.8'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14051.csv
#
# [51/275] Procesando estación: 14052
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14052.txt
#   Estación: EL NOGAL (TAPALPA)
#     Se extrajeron 25611 registros diarios
#     Primeros registros: [{'date': '1946-03-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-03-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-03-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14052.csv
#
# [52/275] Procesando estación: 14053
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14053.txt
#   Estación: EL PINITO (HUEJUQUILLA EL ALTO)
#     Se extrajeron 21032 registros diarios
#     Primeros registros: [{'date': '1964-08-01', 'p': '2.5', 'evap': '4.3', 'tmax': '26.5', 'tmin': '12'}, {'date': '1964-08-02', 'p': '10', 'evap': '5', 'tmax': '27.5', 'tmin': '13'}, {'date': '1964-08-03', 'p': '0', 'evap': '5', 'tmax': '28', 'tmin': '12'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14053.csv
#
# [53/275] Procesando estación: 14054
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14054.txt
#   Estación: EL PUESTO (LAGOS DE MORENO)
#     Se extrajeron 18874 registros diarios
#     Primeros registros: [{'date': '1965-09-02', 'p': '3.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1965-09-03', 'p': '4.3', 'evap': 'NA', 'tmax': '26', 'tmin': '12'}, {'date': '1965-09-04', 'p': '3', 'evap': 'NA', 'tmax': '28', 'tmin': '13'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14054.csv
#
# [54/275] Procesando estación: 14055
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14055.txt
#   Estación: INGENIO EL REFUGIO (TALA)
#     Se extrajeron 4207 registros diarios
#     Primeros registros: [{'date': '1958-06-17', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1958-06-18', 'p': '1', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1958-06-19', 'p': '19', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14055.csv
#
# [55/275] Procesando estación: 14056
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14056.txt
#   Estación: EL SALITRE (SAN MARTÍN HIDALGO)
#     Se extrajeron 20484 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1961-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14056.csv
#
# [56/275] Procesando estación: 14057
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14057.txt
#   Estación: EL SALTO (EL SALTO)
#     Se extrajeron 13952 registros diarios
#     Primeros registros: [{'date': '1948-01-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-01-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-01-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14057.csv
#
# [57/275] Procesando estación: 14058
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14058.txt
#   Estación: EL TECUAN (ENCARNACIÓN DE DÍAZ)
#     Se extrajeron 7122 registros diarios
#     Primeros registros: [{'date': '1970-08-01', 'p': '0', 'evap': '4.4', 'tmax': '28', 'tmin': '11'}, {'date': '1970-08-02', 'p': '0', 'evap': '6.2', 'tmax': '30', 'tmin': '12'}, {'date': '1970-08-03', 'p': '0', 'evap': '4.2', 'tmax': '29', 'tmin': '13'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14058.csv
#
# [58/275] Procesando estación: 14059
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14059.txt
#   Estación: EL TUITO (CABO CORRIENTES)
#     Se extrajeron 21424 registros diarios
#     Primeros registros: [{'date': '1950-10-01', 'p': '8.9', 'evap': 'NA', 'tmax': '38', 'tmin': '14.5'}, {'date': '1950-10-02', 'p': '45.8', 'evap': '3.1', 'tmax': '36.5', 'tmin': '16'}, {'date': '1950-10-03', 'p': '15.4', 'evap': '2.48', 'tmax': '38', 'tmin': '17.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14059.csv
#
# [59/275] Procesando estación: 14060
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14060.txt
#   Estación: EL TULE (ARANDAS)
#     Se extrajeron 17213 registros diarios
#     Primeros registros: [{'date': '1962-06-21', 'p': '5.8', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1962-06-22', 'p': '0.4', 'evap': '6.7', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1962-06-23', 'p': '7.5', 'evap': '6.2', 'tmax': '27', 'tmin': '15'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14060.csv
#
# [60/275] Procesando estación: 14062
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14062.txt
#   Estación: ENCARNACION DE DIAZ (ENCARNACIÓN DE DÍAZ)
#     Se extrajeron 21029 registros diarios
#     Primeros registros: [{'date': '1939-01-01', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '11'}, {'date': '1939-01-02', 'p': '0', 'evap': 'NA', 'tmax': '24', 'tmin': '12'}, {'date': '1939-01-03', 'p': '0', 'evap': 'NA', 'tmax': '26', 'tmin': '13'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14062.csv
#
# [61/275] Procesando estación: 14063
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14063.txt
#   Estación: ETZATLAN (SMN) (ETZATLÁN)
#     Se extrajeron 18868 registros diarios
#     Primeros registros: [{'date': '1948-05-01', 'p': '0', 'evap': 'NA', 'tmax': '33', 'tmin': '14'}, {'date': '1948-05-02', 'p': '0', 'evap': 'NA', 'tmax': '33.5', 'tmin': '15'}, {'date': '1948-05-03', 'p': '0', 'evap': 'NA', 'tmax': '34', 'tmin': '14.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14063.csv
#
# [62/275] Procesando estación: 14064
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14064.txt
#   Estación: EX HACIENDA SAN DIEGO (COCULA)
#     Se extrajeron 13713 registros diarios
#     Primeros registros: [{'date': '1947-06-12', 'p': '0', 'evap': 'NA', 'tmax': '27', 'tmin': '21'}, {'date': '1947-06-13', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '18'}, {'date': '1947-06-14', 'p': '0', 'evap': 'NA', 'tmax': '30', 'tmin': '19'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14064.csv
#
# [63/275] Procesando estación: 14065
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14065.txt
#   Estación: GUADALAJARA (OBS) (GUADALAJARA)
#     Se extrajeron 23891 registros diarios
#     Primeros registros: [{'date': '1882-04-01', 'p': '3', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1882-04-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1882-04-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14065.csv
#
# [64/275] Procesando estación: 14066
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14066.txt
#   Estación: GUADALAJARA (DGE) (GUADALAJARA)
#     Se extrajeron 31247 registros diarios
#     Primeros registros: [{'date': '1930-09-01', 'p': '4', 'evap': 'NA', 'tmax': '28', 'tmin': '16'}, {'date': '1930-09-02', 'p': '1', 'evap': 'NA', 'tmax': '27', 'tmin': '16'}, {'date': '1930-09-03', 'p': '3', 'evap': 'NA', 'tmax': '28', 'tmin': '15'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14066.csv
#
# [65/275] Procesando estación: 14067
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14067.txt
#   Estación: HIGUERA BLANCA (TOMATLÁN)
#     Se extrajeron 23646 registros diarios
#     Primeros registros: [{'date': '1955-04-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-04-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1955-04-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14067.csv
#
# [66/275] Procesando estación: 14068
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14068.txt
#   Estación: HOSTOTIPAQUILLO (HOSTOTIPAQUILLO)
#     Se extrajeron 28097 registros diarios
#     Primeros registros: [{'date': '1939-01-01', 'p': 'NA', 'evap': 'NA', 'tmax': '27.1', 'tmin': '11'}, {'date': '1939-01-02', 'p': 'NA', 'evap': 'NA', 'tmax': '29.1', 'tmin': '11'}, {'date': '1939-01-03', 'p': 'NA', 'evap': 'NA', 'tmax': '28.5', 'tmin': '10'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14068.csv
#
# [67/275] Procesando estación: 14069
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14069.txt
#   Estación: HUEJUCAR (OBS) (HUEJÚCAR)
#     Se extrajeron 21357 registros diarios
#     Primeros registros: [{'date': '1947-02-01', 'p': '0', 'evap': 'NA', 'tmax': '21.5', 'tmin': '9'}, {'date': '1947-02-02', 'p': '0', 'evap': 'NA', 'tmax': '21.5', 'tmin': '6'}, {'date': '1947-02-03', 'p': '0', 'evap': 'NA', 'tmax': '23.5', 'tmin': '2.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14069.csv
#
# [68/275] Procesando estación: 14070
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14070.txt
#   Estación: HUASCATO (DEGOLLADO)
#     Se extrajeron 21246 registros diarios
#     Primeros registros: [{'date': '1964-01-01', 'p': '0', 'evap': '4.2', 'tmax': '20.5', 'tmin': '3'}, {'date': '1964-01-02', 'p': '0', 'evap': '0.3', 'tmax': '16', 'tmin': '5'}, {'date': '1964-01-03', 'p': '7.5', 'evap': '1', 'tmax': '18', 'tmin': '8'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14070.csv
#
# [69/275] Procesando estación: 14071
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14071.txt
#   Estación: HUEJUQUILLA EL ALTO (DGE) (HUEJUQUILLA EL ALTO)
#     Se extrajeron 10871 registros diarios
#     Primeros registros: [{'date': '1986-01-01', 'p': '0', 'evap': '4.4', 'tmax': '25', 'tmin': '7'}, {'date': '1986-01-02', 'p': '0', 'evap': '4.8', 'tmax': '23', 'tmin': '6.5'}, {'date': '1986-01-03', 'p': '0', 'evap': '4.7', 'tmax': '21', 'tmin': '4'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14071.csv
#
# [70/275] Procesando estación: 14072
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14072.txt
#   Estación: HUERTA VIEJA (IXTLAHUACÁN DE LOS MEMBRILLOS)
#     Se extrajeron 26195 registros diarios
#     Primeros registros: [{'date': '1950-10-01', 'p': '3.1', 'evap': '5.39', 'tmax': '26', 'tmin': '17'}, {'date': '1950-10-02', 'p': '2.1', 'evap': '5.63', 'tmax': '27', 'tmin': '17'}, {'date': '1950-10-03', 'p': '0', 'evap': '3.76', 'tmax': '26', 'tmin': '12.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14072.csv
#
# [71/275] Procesando estación: 14073
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14073.txt
#   Estación: IXTLAHUACAN DEL RIO (IXTLAHUACÁN DEL RÍO)
#     Se extrajeron 20627 registros diarios
#     Primeros registros: [{'date': '1943-06-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-06-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1943-06-03', 'p': '0.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14073.csv
#
# [72/275] Procesando estación: 14074
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14074.txt
#   Estación: JALOSTOTITLAN (JALOSTOTITLÁN)
#     Se extrajeron 22926 registros diarios
#     Primeros registros: [{'date': '1941-11-01', 'p': '11.1', 'evap': 'NA', 'tmax': '27', 'tmin': '16'}, {'date': '1941-11-02', 'p': '7.3', 'evap': 'NA', 'tmax': '28', 'tmin': '14'}, {'date': '1941-11-03', 'p': '1.3', 'evap': 'NA', 'tmax': '29', 'tmin': '15'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14074.csv
#
# [73/275] Procesando estación: 14075
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14075.txt
#   Estación: JAMAY (JAMAY)
#     Se extrajeron 24172 registros diarios
#     Primeros registros: [{'date': '1948-02-01', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-02-02', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-02-03', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14075.csv
#
# [74/275] Procesando estación: 14076
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14076.txt
#   Estación: JESUS MARIA (JESÚS MARÍA)
#     Se extrajeron 27690 registros diarios
#     Primeros registros: [{'date': '1944-02-01', 'p': '0', 'evap': 'NA', 'tmax': '23', 'tmin': '8'}, {'date': '1944-02-02', 'p': '0.5', 'evap': 'NA', 'tmax': '22', 'tmin': '8.5'}, {'date': '1944-02-03', 'p': '5', 'evap': 'NA', 'tmax': '18', 'tmin': '10'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14076.csv
#
# [75/275] Procesando estación: 14077
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14077.txt
#   Estación: JOCOTEPEC (JOCOTEPEC)
#     Se extrajeron 18879 registros diarios
#     Primeros registros: [{'date': '1946-07-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-07-02', 'p': '5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1946-07-03', 'p': '10.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14077.csv
#
# [76/275] Procesando estación: 14078
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14078.txt
#   Estación: JUCHITLAN (JUCHITLÁN)
#     Se extrajeron 26111 registros diarios
#     Primeros registros: [{'date': '1948-02-01', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-02-02', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1948-02-03', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14078.csv
#
# [77/275] Procesando estación: 14079
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14079.txt
#   Estación: LA COFRADIA (VILLA PURIFICACIÓN)
#     Se extrajeron 5869 registros diarios
#     Primeros registros: [{'date': '1965-07-01', 'p': '2', 'evap': 'NA', 'tmax': '32.5', 'tmin': '20'}, {'date': '1965-07-02', 'p': '4', 'evap': 'NA', 'tmax': '32.5', 'tmin': '20.5'}, {'date': '1965-07-03', 'p': '16.5', 'evap': 'NA', 'tmax': '31.5', 'tmin': '19.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14079.csv
#
# [78/275] Procesando estación: 14080
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14080.txt
#   Estación: LA CUÑA (YAHUALICA DE GONZÁLEZ GALLO)
#     Se extrajeron 25102 registros diarios
#     Primeros registros: [{'date': '1949-06-01', 'p': '0', 'evap': 'NA', 'tmax': '35.2', 'tmin': '20'}, {'date': '1949-06-02', 'p': '0', 'evap': 'NA', 'tmax': '35.3', 'tmin': '16.9'}, {'date': '1949-06-03', 'p': '28.6', 'evap': 'NA', 'tmax': '36', 'tmin': '12.6'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14080.csv
#
# [79/275] Procesando estación: 14081
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14081.txt
#   Estación: LA DESEMBOCADA (PUERTO VALLARTA)
#     Se extrajeron 25348 registros diarios
#     Primeros registros: [{'date': '1949-06-15', 'p': '3.5', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1949-06-16', 'p': '7.2', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1949-06-17', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14081.csv
#
# [80/275] Procesando estación: 14082
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14082.txt
#   Estación: LA ESTANZUELA (TEUCHITLÁN)
#     Se extrajeron 5262 registros diarios
#     Primeros registros: [{'date': '1961-01-01', 'p': '0', 'evap': '5', 'tmax': '28', 'tmin': '8'}, {'date': '1961-01-02', 'p': '0', 'evap': '3.3', 'tmax': '28.2', 'tmin': '5'}, {'date': '1961-01-03', 'p': '0', 'evap': '3.6', 'tmax': '30.2', 'tmin': '5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14082.csv
#
# [81/275] Procesando estación: 14083
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14083.txt
#   Estación: LAGOS DE MORENO (OBS) (LAGOS DE MORENO)
#     Se extrajeron 23373 registros diarios
#     Primeros registros: [{'date': '1958-05-09', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1958-05-10', 'p': '0', 'evap': '13.24', 'tmax': '40', 'tmin': '15'}, {'date': '1958-05-11', 'p': '0', 'evap': '8.23', 'tmax': '40', 'tmin': '10'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14083.csv
#
# [82/275] Procesando estación: 14084
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14084.txt
#   Estación: LAGOS DE MORENO (DGE) (LAGOS DE MORENO)
#     Se extrajeron 29554 registros diarios
#     Primeros registros: [{'date': '1942-01-01', 'p': '0', 'evap': 'NA', 'tmax': '30.5', 'tmin': '10'}, {'date': '1942-01-02', 'p': '0', 'evap': 'NA', 'tmax': '28', 'tmin': '11'}, {'date': '1942-01-03', 'p': '0', 'evap': 'NA', 'tmax': '30', 'tmin': '12'}]
# ...
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14368.csv
#
# [261/275] Procesando estación: 14369
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14369.txt
#   Estación: LA VAQUERA (ARANDAS)
#     Se extrajeron 14792 registros diarios
#     Primeros registros: [{'date': '1981-07-01', 'p': '0.3', 'evap': '1.95', 'tmax': '24', 'tmin': '13.5'}, {'date': '1981-07-02', 'p': '7.2', 'evap': '3.15', 'tmax': '23', 'tmin': '14'}, {'date': '1981-07-03', 'p': '0', 'evap': '5.5', 'tmax': '23', 'tmin': '13.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14369.csv
#
# [262/275] Procesando estación: 14373
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14373.txt
#   Estación: AGUA PRIETA (ZAPOPAN)
#     Se extrajeron 3529 registros diarios
#     Primeros registros: [{'date': '1985-01-01', 'p': '0', 'evap': '2.6', 'tmax': '27', 'tmin': '7.5'}, {'date': '1985-01-02', 'p': '0', 'evap': '2.5', 'tmax': '26', 'tmin': '7'}, {'date': '1985-01-03', 'p': '0', 'evap': '2.9', 'tmax': '25.5', 'tmin': '5.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14373.csv
#
# [263/275] Procesando estación: 14376
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14376.txt
#   Estación: AYOTLAN (AYOTLÁN)
#     Se extrajeron 731 registros diarios
#     Primeros registros: [{'date': '1999-01-01', 'p': '0', 'evap': '4.46', 'tmax': '24.5', 'tmin': '11'}, {'date': '1999-01-02', 'p': '0', 'evap': '6.5', 'tmax': '24', 'tmin': '9.5'}, {'date': '1999-01-03', 'p': '0', 'evap': '4.44', 'tmax': '25.5', 'tmin': '10'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14376.csv
#
# [264/275] Procesando estación: 14377
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14377.txt
#   Estación: LA PRIMAVERA (COCULA)
#     Se extrajeron 516 registros diarios
#     Primeros registros: [{'date': '1989-01-01', 'p': '0', 'evap': '3.05', 'tmax': '27', 'tmin': '7'}, {'date': '1989-01-02', 'p': '0', 'evap': '3.5', 'tmax': '28', 'tmin': '6'}, {'date': '1989-01-03', 'p': '0', 'evap': '5.2', 'tmax': '27', 'tmin': '9'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14377.csv
#
# [265/275] Procesando estación: 14379
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14379.txt
#   Estación: MEZCALA (PONCITLÁN)
#     Se extrajeron 15535 registros diarios
#     Primeros registros: [{'date': '1982-01-01', 'p': '0', 'evap': '3.39', 'tmax': '25.6', 'tmin': '5.5'}, {'date': '1982-01-02', 'p': '0.01', 'evap': '4', 'tmax': '25.7', 'tmin': '5'}, {'date': '1982-01-03', 'p': '0.01', 'evap': '3.79', 'tmax': '25.7', 'tmin': '4.6'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14379.csv
#
# [266/275] Procesando estación: 14380
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14380.txt
#   Estación: SAN LUIS (TLAJOMULCO DE ZÚÑIGA)
#     Se extrajeron 458 registros diarios
#     Primeros registros: [{'date': '2001-01-01', 'p': '0', 'evap': '4.7', 'tmax': '33', 'tmin': '5.5'}, {'date': '2001-01-02', 'p': '0', 'evap': '3.02', 'tmax': '37', 'tmin': '5.5'}, {'date': '2001-01-03', 'p': '0', 'evap': '7.03', 'tmax': '30', 'tmin': '5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14380.csv
#
# [267/275] Procesando estación: 14386
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14386.txt
#   Estación: TONALA (TONALÁ)
#     Se extrajeron 11212 registros diarios
#     Primeros registros: [{'date': '1991-01-01', 'p': '0', 'evap': '6.79', 'tmax': '26', 'tmin': '10.5'}, {'date': '1991-01-02', 'p': '0', 'evap': '4.65', 'tmax': '27', 'tmin': '11'}, {'date': '1991-01-03', 'p': '0', 'evap': '4.67', 'tmax': '27', 'tmin': '12'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14386.csv
#
# [268/275] Procesando estación: 14387
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14387.txt
#   Estación: TONAYA (TONAYA)
#     Se extrajeron 3343 registros diarios
#     Primeros registros: [{'date': '1991-06-01', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1991-06-02', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1991-06-03', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14387.csv
#
# [269/275] Procesando estación: 14388
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14388.txt
#   Estación: ZAPOTLANEJO (DGE) (ZAPOTLANEJO)
#     Se extrajeron 2176 registros diarios
#     Primeros registros: [{'date': '1986-10-07', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1986-10-08', 'p': '31.5', 'evap': '6.25', 'tmax': '26', 'tmin': '11'}, {'date': '1986-10-09', 'p': '0', 'evap': '1.98', 'tmax': '26', 'tmin': '16'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14388.csv
#
# [270/275] Procesando estación: 14390
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14390.txt
#   Estación: EL CORCOVADO (AUTLÁN DE NAVARRO)
#     Se extrajeron 9037 registros diarios
#     Primeros registros: [{'date': '1974-01-01', 'p': '0', 'evap': '3.83', 'tmax': '30', 'tmin': '9'}, {'date': '1974-01-02', 'p': '0', 'evap': '3.7', 'tmax': '29', 'tmin': '9'}, {'date': '1974-01-03', 'p': '0', 'evap': '4.2', 'tmax': '30', 'tmin': '11'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14390.csv
#
# [271/275] Procesando estación: 14391
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14391.txt
#   Estación: PRESA EL VOLANTIN (TIZAPÁN EL ALTO)
#     Se extrajeron 12110 registros diarios
#     Primeros registros: [{'date': '1989-09-01', 'p': '18', 'evap': '3.1', 'tmax': '21', 'tmin': '14'}, {'date': '1989-09-02', 'p': '17', 'evap': '2.9', 'tmax': '20', 'tmin': '12'}, {'date': '1989-09-03', 'p': '6.5', 'evap': '4', 'tmax': '22', 'tmin': '12'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14391.csv
#
# [272/275] Procesando estación: 14392
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14392.txt
#   Estación: PASO DEL CUARENTA II (LAGOS DE MORENO)
#     Se extrajeron 10684 registros diarios
#     Primeros registros: [{'date': '1990-01-18', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1990-01-19', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1990-01-20', 'p': 'NA', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14392.csv
#
# [273/275] Procesando estación: 14395
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14395.txt
#   Estación: IXTLAHUACAN DE SANTIAGO (UNIÓN DE TULA)
#     Se extrajeron 5703 registros diarios
#     Primeros registros: [{'date': '1995-01-01', 'p': '0', 'evap': '6.31', 'tmax': '23', 'tmin': '8'}, {'date': '1995-01-02', 'p': '0', 'evap': '5.79', 'tmax': '23', 'tmin': '10'}, {'date': '1995-01-03', 'p': '0', 'evap': '6.47', 'tmax': '23', 'tmin': '10'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14395.csv
#
# [274/275] Procesando estación: 14396
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14396.txt
#   Estación: PIEDRA BARRENADA (JOCOTEPEC)
#     Se extrajeron 11498 registros diarios
#     Primeros registros: [{'date': '1991-06-01', 'p': '0', 'evap': '8.38', 'tmax': '33', 'tmin': '19'}, {'date': '1991-06-02', 'p': '0', 'evap': '7.32', 'tmax': '36', 'tmin': '19'}, {'date': '1991-06-03', 'p': '0', 'evap': '8.28', 'tmax': '34.5', 'tmin': '19.5'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14396.csv
#
# [275/275] Procesando estación: 14397
#   Descargando de: https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/jal/dia14397.txt
#   Estación: PRESA CALDERON (ZAPOTLANEJO)
#     Se extrajeron 12045 registros diarios
#     Primeros registros: [{'date': '1991-08-22', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1991-08-23', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}, {'date': '1991-08-24', 'p': '0', 'evap': 'NA', 'tmax': 'NA', 'tmin': 'NA'}]
#   Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/diarios_14397.csv
#
# ¡Proceso completado!
# Estaciones con datos extraídos: 275/275
# Datos guardados en: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS
#
# Reporte generado: /content/drive/MyDrive/Clima_Jalisco/DATOS_DIARIOS/reporte_estaciones.csv
# Total de estaciones con datos: 275
#   14001: 4429 registros
#   14002: 22289 registros
#   14004: 9876 registros
#   14005: 8994 registros
#   14006: 30156 registros
#   14007: 5026 registros
#   14008: 10526 registros
#   14009: 29640 registros
#   14010: 16495 registros
#   14011: 22304 registros
#   14012: 6322 registros
#   14013: 21232 registros
#   14014: 14571 registros
#   14015: 16481 registros
#   14016: 26401 registros
#   14017: 26760 registros
#   14018: 28386 registros
#   14019: 17516 registros
#   14020: 14148 registros
#   14021: 9473 registros
#   14022: 1152 registros
#   14023: 27741 registros
#   14024: 23399 registros
#   14025: 18362 registros
#   14026: 23605 registros
#   14027: 15680 registros
#   14028: 26569 registros
#   14029: 18507 registros
#   14030: 32678 registros
#   14031: 15333 registros
#   14032: 15038 registros
#   14033: 17755 registros
#   14034: 19145 registros
#   14035: 22026 registros
#   14036: 23908 registros
#   14037: 14478 registros
#   14038: 25602 registros
#   14039: 28196 registros
#   14040: 32709 registros
#   14041: 7027 registros
#   14042: 12080 registros
#   14043: 22192 registros
#   14044: 22013 registros
#   14045: 3730 registros
#   14046: 17244 registros
#   14047: 22079 registros
#   14048: 23476 registros
#   14049: 9465 registros
#   14050: 16966 registros
#   14051: 10677 registros
#   14052: 25611 registros
#   14053: 21032 registros
#   14054: 18874 registros
#   14055: 4207 registros
#   14056: 20484 registros
#   14057: 13952 registros
#   14058: 7122 registros
#   14059: 21424 registros
#   14060: 17213 registros
#   14062: 21029 registros
#   14063: 18868 registros
#   14064: 13713 registros
#   14065: 23891 registros
#   14066: 31247 registros
#   14067: 23646 registros
#   14068: 28097 registros
#   14069: 21357 registros
#   14070: 21246 registros
#   14071: 10871 registros
#   14072: 26195 registros
#   14073: 20627 registros
#   14074: 22926 registros
#   14075: 24172 registros
#   14076: 27690 registros
#   14077: 18879 registros
#   14078: 26111 registros
#   14079: 5869 registros
#   14080: 25102 registros
#   14081: 25348 registros
#   14082: 5262 registros
#   14083: 23373 registros
#   14084: 29554 registros
#   14085: 16924 registros
#   14086: 21479 registros
#   14087: 22476 registros
#   14088: 2736 registros
#   14089: 24329 registros
#   14090: 19779 registros
#   14091: 8468 registros
#   14092: 4533 registros
#   14093: 27763 registros
#   14094: 9127 registros
#   14095: 9002 registros
#   14096: 34714 registros
#   14097: 3887 registros
#   14098: 8523 registros
#   14099: 26637 registros
#   14100: 27624 registros
#   14101: 21949 registros
#   14102: 1432 registros
#   14103: 15756 registros
#   14104: 24640 registros
#   14105: 9565 registros
#   14106: 17678 registros
#   14107: 13571 registros
#   14108: 11365 registros
#   14109: 9013 registros
#   14110: 12311 registros
#   14111: 26744 registros
#   14112: 5019 registros
#   14113: 24986 registros
#   14114: 22942 registros
#   14115: 9150 registros
#   14116: 21680 registros
#   14117: 21297 registros
#   14118: 28848 registros
#   14119: 12355 registros
#   14120: 2656 registros
#   14121: 13912 registros
#   14122: 29141 registros
#   14123: 27975 registros
#   14124: 7575 registros
#   14125: 28154 registros
#   14126: 17074 registros
#   14127: 10259 registros
#   14128: 17622 registros
#   14129: 20428 registros
#   14130: 10530 registros
#   14131: 20418 registros
#   14132: 26642 registros
#   14133: 12987 registros
#   14134: 6796 registros
#   14135: 14171 registros
#   14136: 24114 registros
#   14138: 9399 registros
#   14139: 19667 registros
#   14140: 16786 registros
#   14141: 31333 registros
#   14142: 29263 registros
#   14143: 28718 registros
#   14144: 23610 registros
#   14145: 30304 registros
#   14146: 20126 registros
#   14147: 14803 registros
#   14148: 16049 registros
#   14149: 2953 registros
#   14151: 13256 registros
#   14152: 18913 registros
#   14153: 18392 registros
#   14154: 22070 registros
#   14155: 22346 registros
#   14156: 27060 registros
#   14157: 21614 registros
#   14158: 25051 registros
#   14159: 17164 registros
#   14160: 20103 registros
#   14161: 2618 registros
#   14162: 12908 registros
#   14163: 8193 registros
#   14164: 22042 registros
#   14165: 26661 registros
#   14166: 13197 registros
#   14167: 27382 registros
#   14168: 24572 registros
#   14169: 26086 registros
#   14170: 12151 registros
#   14171: 22221 registros
#   14173: 10733 registros
#   14174: 9100 registros
#   14175: 17181 registros
#   14176: 12066 registros
#   14177: 10785 registros
#   14178: 14015 registros
#   14179: 11891 registros
#   14180: 26206 registros
#   14182: 5298 registros
#   14183: 8293 registros
#   14184: 10623 registros
#   14185: 10711 registros
#   14186: 9973 registros
#   14187: 17467 registros
#   14188: 5135 registros
#   14189: 14987 registros
#   14190: 5021 registros
#   14191: 10227 registros
#   14192: 7458 registros
#   14195: 9889 registros
#   14196: 9405 registros
#   14197: 4697 registros
#   14198: 4516 registros
#   14199: 3742 registros
#   14200: 3356 registros
#   14202: 2526 registros
#   14266: 22046 registros
#   14269: 17747 registros
#   14271: 4212 registros
#   14276: 8155 registros
#   14277: 1218 registros
#   14278: 2073 registros
#   14279: 3579 registros
#   14280: 9351 registros
#   14281: 1312 registros
#   14287: 3943 registros
#   14292: 3182 registros
#   14294: 9421 registros
#   14295: 692 registros
#   14296: 2762 registros
#   14297: 12760 registros
#   14301: 9855 registros
#   14302: 1199 registros
#   14304: 9855 registros
#   14306: 15704 registros
#   14307: 3992 registros
#   14308: 3646 registros
#   14309: 3872 registros
#   14310: 2364 registros
#   14311: 15871 registros
#   14312: 4059 registros
#   14313: 2039 registros
#   14314: 2545 registros
#   14315: 6132 registros
#   14316: 3129 registros
#   14317: 11463 registros
#   14318: 1517 registros
#   14319: 9577 registros
#   14320: 14670 registros
#   14322: 6179 registros
#   14323: 2396 registros
#   14324: 15330 registros
#   14325: 2020 registros
#   14326: 14772 registros
#   14327: 3424 registros
#   14329: 15923 registros
#   14330: 4255 registros
#   14331: 13145 registros
#   14333: 3133 registros
#   14336: 14796 registros
#   14337: 15554 registros
#   14338: 5355 registros
#   14339: 16109 registros
#   14340: 1635 registros
#   14342: 787 registros
#   14343: 16016 registros
#   14344: 1452 registros
#   14345: 10177 registros
#   14346: 15923 registros
#   14347: 3324 registros
#   14348: 13799 registros
#   14349: 15910 registros
#   14350: 15855 registros
#   14351: 15789 registros
#   14352: 13377 registros
#   14355: 12979 registros
#   14356: 1676 registros
#   14360: 4231 registros
#   14362: 1976 registros
#   14363: 2257 registros
#   14365: 2142 registros
#   14367: 10883 registros
#   14368: 7436 registros
#   14369: 14792 registros
#   14373: 3529 registros
#   14376: 731 registros
#   14377: 516 registros
#   14379: 15535 registros
#   14380: 458 registros
#   14386: 11212 registros
#   14387: 3343 registros
#   14388: 2176 registros
#   14390: 9037 registros
#   14391: 12110 registros
#   14392: 10684 registros
#   14395: 5703 registros
#   14396: 11498 registros
#   14397: 12045 registros
